# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/GitHub/

username = 'roelhulsman'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/conformal_classification
# !git clone https://{git_token}@github.com/{username}/cqr
# !git clone https://{git_token}@github.com/{username}/ltt
# !git clone https://{git_token}@github.com/{username}/rcps
# Out:
# /content/drive/MyDrive/GitHub
# fatal: destination path 'conformal_classification' already exists and is not an empty directory.
# fatal: destination path 'cqr' already exists and is not an empty directory.
# fatal: destination path 'ltt' already exists and is not an empty directory.
# fatal: destination path 'rcps' already exists and is not an empty directory.

# %%
# %cd dissertation
# Out:
# /content/drive/MyDrive/GitHub/dissertation

# %%
# !git config --global user.email "roel.hulsman@outlook.com"
# !git config --global user.name "Roel Hulsman"

# !git add .
# !git status
# Out:
# [main 9cd778f] edited file
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git commit -m "edited file"

# %%
# !git push -u origin "main"
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1.05 KiB | 214.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/roelhulsman/dissertation.git
#    20752b3..9cd778f  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
