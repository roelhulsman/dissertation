# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GitHub/

username = 'roelhulsman'
repository = 'conformal_classification'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'conformal_classification'...
# remote: Enumerating objects: 623, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 623 (delta 39), reused 39 (delta 39), pack-reused 558
# Receiving objects: 100% (623/623), 4.33 MiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (424/424), done.

# %%
# %cd /content/drive/MyDrive/GitHub/

username = 'roelhulsman'
repository = 'cqr'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# /content/drive/MyDrive/GitHub
# Cloning into 'cqr'...
# remote: Enumerating objects: 1152, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 1152 (delta 0), reused 1 (delta 0), pack-reused 1148
# Receiving objects: 100% (1152/1152), 5.14 MiB | 5.37 MiB/s, done.
# Resolving deltas: 100% (728/728), done.

# %%
# %cd /content/drive/MyDrive/GitHub/

username = 'roelhulsman'
repository = 'ltt'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# /content/drive/MyDrive/GitHub
# Cloning into 'ltt'...
# remote: Enumerating objects: 1619, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1619 (delta 9), reused 18 (delta 6), pack-reused 1589
# Receiving objects: 100% (1619/1619), 20.40 MiB | 8.96 MiB/s, done.
# Resolving deltas: 100% (989/989), done.
# Checking out files: 100% (108/108), done.

# %%
# %cd /content/drive/MyDrive/GitHub/

username = 'roelhulsman'
repository = 'rcps'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# /content/drive/MyDrive/GitHub
# Cloning into 'rcps'...
# remote: Enumerating objects: 852, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 852 (delta 55), reused 78 (delta 22), pack-reused 718
# Receiving objects: 100% (852/852), 23.87 MiB | 11.51 MiB/s, done.
# Resolving deltas: 100% (386/386), done.
# Checking out files: 100% (141/141), done.
