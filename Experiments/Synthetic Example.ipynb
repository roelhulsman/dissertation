# %% [markdown]
# # Tolerance Regions: A synthetic example (based on [1])
#
# In this tutorial we will create synthetic 1-dimensional heteroscedastic data, and use the conformalized quantile regression (CQR) [1] to create a tolerance region. The regression function used in this experiment is random forests.
#
# [1] Yaniv Romano, Evan Patterson, and Emmanuel J. Candes, “Conformalized quantile regression.” 2019.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GitHub/dissertation
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GitHub/dissertation

# %%
# !pip install scikit-garden
# !pip install scikit-learn==0.21.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-garden
#   Downloading scikit-garden-0.1.3.tar.gz (317 kB)
#      |████████████████████████████████| 317 kB 8.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scikit-garden) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from scikit-garden) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from scikit-garden) (1.0.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from scikit-garden) (0.29.32)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->scikit-garden) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->scikit-garden) (1.1.0)
# Building wheels for collected packages: scikit-garden
#   Building wheel for scikit-garden (setup.py) ... done
#   Created wheel for scikit-garden: filename=scikit_garden-0.1.3-cp37-cp37m-linux_x86_64.whl size=671891 sha256=e5cf7a114d5b3083a9d32b9fbcd3937642bc68e87f3e51efcdf42371d5105019
#   Stored in directory: /root/.cache/pip/wheels/10/06/27/3687df098199aadafad4cb3061bd59e86d3e4bb7428edd0d66
# Successfully built scikit-garden
# Installing collected packages: scikit-garden
# Successfully installed scikit-garden-0.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.21.3
#   Downloading scikit_learn-0.21.3-cp37-cp37m-manylinux1_x86_64.whl (6.7 MB)
#      |████████████████████████████████| 6.7 MB 6.2 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21.3) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21.3) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21.3) (1.7.3)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.21.3 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.21.3 which is incompatible.
# Successfully installed scikit-learn-0.21.3

# %% [markdown]
# We start by defining the desired parameters, and some hyper-parameters of random forests. These parameters are used by the conditional quantile random forests regression.

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
np.warnings.filterwarnings('ignore')
import pandas as pd
from cqr import helper
from nonconformist.nc import RegressorNc
from nonconformist.cp import IcpRegressor
from nonconformist.nc import QuantileRegErrFunc
import timeit
import random
import torch
from scipy.stats import binom, beta, betabinom
from statsmodels.distributions.empirical_distribution import ECDF

cqr_color = '#1f77b4'
beta_binom_color = '#ff7f0e'
beta_color = '#2ca02c'
qr_color = '#d62728'

# %matplotlib inline

seed = 23
#seed = 19
#seed = 17
#seed = 13
#seed = 11
#seed = 7
#seed = 5
#seed = 3
#seed = 2
#seed = 1

# number of datapoints
n_train = 1000
n_cal = 1000
n_test = 5000

# desired tolerance region 
eps = 0.1
delta = 0.1

# number of loops
R = 1000

# desired expected miscoverage error
alpha = (max(np.where(binom.cdf(range(n_cal), n_cal, eps)<=delta)[-1])+1)/(n_cal+1)

# low and high target quantiles
quantiles = [100*alpha/2, 100*(1-alpha/2)]

# define quantile random forests (QRF) parameters
params_qforest = dict()
params_qforest["n_estimators"] = 100
params_qforest["min_samples_leaf"] = 40
params_qforest["max_features"] = 1
params_qforest["CV"] = True
params_qforest["coverage_factor"] = 0.9
params_qforest["test_ratio"] = 0.1
params_qforest["random_state"] = seed
params_qforest["range_vals"] = 30
params_qforest["num_vals"] = 10

# maximal number of testpoints to plot
max_show = 1000

# save figures and runs?
save_figures = True
save_run = True
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/gradient_boosting.py:32: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/gradient_boosting.py:32: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [markdown]
# The following graph function plots the test data and saves to drive

# %%
def plot_func(x,
              y,
              y_u=None,
              y_l=None,
              pred=None,
              shade_color="",
              method_name="",
              title="",
              filename=None,
              save_figures=False):
    
    """ Scatter plot of (x,y) points along with the constructed prediction interval 
    
    Parameters
    ----------
    x : numpy array, corresponding to the feature of each of the n samples
    y : numpy array, target response variable (length n)
    pred : numpy array, the estimated prediction. It may be the conditional mean,
           or low and high conditional quantiles.
    shade_color : string, desired color of the prediciton interval
    method_name : string, name of the method
    title : string, the title of the figure
    filename : sting, name of the file to save the figure
    save_figures : boolean, save the figure (True) or not (False)
    
    """
    
    x_ = x[:max_show]
    y_ = y[:max_show]
    if y_u is not None:
        y_u_ = y_u[:max_show]
    if y_l is not None:
        y_l_ = y_l[:max_show]
    if pred is not None:
        pred_ = pred[:max_show]

    fig = plt.figure()
    inds = np.argsort(np.squeeze(x_))
    plt.plot(x_[inds,:], y_[inds], 'k.', alpha=.2, markersize=10,
             fillstyle='none', label=u'Observations')
    
    if (y_u is not None) and (y_l is not None):
        plt.fill(np.concatenate([x_[inds], x_[inds][::-1]]),
                 np.concatenate([y_u_[inds], y_l_[inds][::-1]]),
                 alpha=.5, fc=shade_color, ec='None',
                 label = method_name + ' prediction interval')
    
    if pred is not None:
        if pred_.ndim == 2:
            plt.plot(x_[inds,:], pred_[inds,0], 'k', lw=2, alpha=0.9,
                     label=u'QR predicted quantiles')
            plt.plot(x_[inds,:], pred_[inds,1], 'k', lw=2, alpha=0.9)
        else:
            plt.plot(x_[inds,:], pred_[inds], 'k--', lw=2, alpha=0.9,
                     label=u'Predicted value')
    
    plt.ylim([-2.5, 7])
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='upper right')
    if save_figures and (filename is not None):
        plt.savefig(filename, bbox_inches='tight', dpi=300)
    
    plt.show()

# %% [markdown]
# ## **Synthetic data example**
#
# Here we generate our training and test samples $(X_i,Y_i)$. To generate the training data, we draw $n=2000$ independent, univariate predictor samples $X_i$ from the uniform distribution on the interval $[1,5]$. The response variable is then sampled as $$ Y_i \sim \textrm{Pois}(\sin^2(X_i) + 0.1) + 0.03 X_i \epsilon_{1,i} + 25 \mathbb{1}\{ U_i < 0.01 \} \epsilon_{2,i},$$ where $\textrm{Pois}(\lambda)$ is the Poisson distribution with mean $\lambda$, both $\epsilon_{1,i}$ and $\epsilon_{2,i}$ are i.i.d.\ standard Gaussian noise, and the $U_i$ are uniform on the interval $[0,1]$. The last term in the equation above creates a few but large outliers. We generate a test set of 5000 samples in the same way.

# %%
def f(x):
    ''' Construct data (1D example)
    '''
    ax = 0*x
    for i in range(len(x)):
        ax[i] = np.random.poisson(np.sin(x[i])**2+0.1) + 0.03*x[i]*np.random.randn(1)
        ax[i] += 25*(np.random.uniform(0,1,1)<0.01)*np.random.randn(1)
    return ax.astype(float)

# %% [markdown]
# Generate and plot data

# %%
np.random.seed(seed)
  
# training calibration and test features
x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

# generate labels
y_train = f(x_train)
y_cal = f(x_cal)
y_test = f(x_test)

# reshape the features
x_train = np.reshape(x_train,(n_train, 1))
x_cal = np.reshape(x_cal,(n_cal, 1))
x_test = np.reshape(x_test,(n_test, 1))

# display the test data in full range (including the outliers)
fig = plt.figure()
plt.plot(x_test, y_test, 'k.', alpha = 0.3, markersize=10,
         fillstyle='none', label=u'Observations')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
if save_figures:
    plt.savefig("Images/test_data.png",
                bbox_inches='tight', dpi=300)
plt.show()

# display the test data without outliers (zoom in)
plot_func(x_test,y_test,filename="Images/test_data_zoom.png", save_figures=save_figures)

# %% [markdown]
# Fit base predictor

# %%
start = timeit.default_timer()

# define the QRF model
quantile_estimator = helper.QuantileForestRegressorAdapter(model=None,
                                                           fit_params=None,
                                                           quantiles=quantiles,
                                                           params=params_qforest)

# define the CQR object, computing the absolute residual error of points 
# located outside the estimated QRF band 
nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

# build the split CQR object
icp = IcpRegressor(nc)

# fit the conditional quantile regression to the proper training data
icp.fit(x_train, y_train)

# compute the absolute errors on calibration data
icp.calibrate(x_cal, y_cal)

# produce predictions for the test set, with confidence equal to significance
predictions = icp.predict(x_test, significance=alpha)
y_lower = predictions[:,0]
y_upper = predictions[:,1]

# compute the low and high conditional quantile estimation
pred_qr = quantile_estimator.predict(x_test)
y_lower_qr = pred_qr[:,0]
y_upper_qr = pred_qr[:,1]

stop = timeit.default_timer()
print('CQR + QR QRF: Time: ', stop - start)
# Out:
# CQR + QR QRF: Time:  24.276406167999966

# %% [markdown]
# Estimate performance of CQR and base predictor on test set, together with interval length and estimate of lambda. Visualize with graphs

# %%
# compute and display the average coverage
in_the_range = np.sum((y_test >= y_lower) & (y_test <= y_upper))
in_the_range_qr = np.sum((y_test >= y_lower_qr) & (y_test <= y_upper_qr))
print("CQR QRF: Percentage in the range (expecting " + str(100*(1-alpha)) + "%):",
      in_the_range / len(y_test) * 100)
print("QR QRF : Percentage in the range (expecting " + str(100*(1-alpha)*params_qforest["coverage_factor"]) + "%):",
      in_the_range_qr / len(y_test) * 100)

# compute length of the conformal interval per each test point
length_cqr_rf = y_upper - y_lower
length_qr_rf = y_upper_qr - y_lower_qr

# compute and display the average length
print("CQR QRF: Average length:", np.mean(length_cqr_rf))
print("QR QRF : Average length:", np.mean(length_qr_rf))

# compute and display the value of lambda
print("CQR QRF: Lambda:", y_upper[0]-y_upper_qr[0])

# display the results
plot_func(x=x_test,y=y_test,y_u=y_upper,y_l=y_lower,pred=pred_qr,shade_color=cqr_color,
          method_name="CQR:", filename="Images/cqr.png",save_figures=save_figures)

# Display length of interval as function of X
fig = plt.figure()
inds = np.argsort(np.squeeze(x_test))

plt.plot(x_test[inds,:], length_cqr_rf[inds], cqr_color, lw=4, label=u'CQR', alpha=0.9)

plt.xlabel('$X$')
plt.ylabel('Length')
plt.legend(loc='upper left')
if save_figures:
    plt.savefig("Images/cqr_length.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# CQR QRF: Percentage in the range (expecting 91.20879120879121%): 92.25999999999999
# QR QRF : Percentage in the range (expecting 82.08791208791209%): 83.98
# CQR QRF: Average length: 2.0875833736021674
# QR QRF : Average length: 1.9697355958667286
# CQR QRF: Lambda: 0.05892388886771949

# %% [markdown]
# ## **QRF and CQR 1 predictor simultaenously (NOT USED IN FINAL DRAFT)**
#
# Here we fit $R=1000$ trials of QRF and CQR procedure using the same proper training set for each trial. We start with the hyperparameters

# %%
# define quantile random forests (QRF) parameters
params_qforest = dict()
params_qforest["n_estimators"] = 100
params_qforest["min_samples_leaf"] = 40
params_qforest["max_features"] = 1
params_qforest["CV"] = True
params_qforest["coverage_factor"] = 0.9
params_qforest["test_ratio"] = 0.1
params_qforest["random_state"] = seed
params_qforest["range_vals"] = 30
params_qforest["num_vals"] = 10

# define quantile random forests (QRF) parameters
params_qforest_qrf = dict()
params_qforest_qrf["n_estimators"] = 100
params_qforest_qrf["min_samples_leaf"] = 40
params_qforest_qrf["max_features"] = 1
params_qforest_qrf["CV"] = False
params_qforest_qrf["random_state"] = seed

# %% [markdown]
# Fit base predictor

# %%
np.random.seed(seed)

start = timeit.default_timer()

# training features
x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

# generate labels
y_train = f(x_train)
y_test = f(x_test)

# reshape the features
x_train = np.reshape(x_train,(n_train, 1))
x_test = np.reshape(x_test,(n_test,1))

# define the QRF model
quantile_estimator = helper.QuantileForestRegressorAdapter(model=None,
                                                           fit_params=None,
                                                           quantiles=quantiles,
                                                           params=params_qforest)

# define the CQR object, computing the absolute residual error of points 
# located outside the estimated QRF band 
nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

# build the split CQR object
icp = IcpRegressor(nc)

# fit the conditional quantile regression to the proper training data
icp.fit(x_train, y_train)

# compute the low and high conditional quantile estimation
pred_qr_qrf = quantile_estimator.predict(x_test)
y_lower_qr_qrf = pred_qr_qrf[:,0]
y_upper_qr_qrf = pred_qr_qrf[:,1]

# compute and display the average coverage
in_the_range_qr_qrf = np.sum((y_test >= y_lower_qr_qrf) & (y_test <= y_upper_qr_qrf))
print("QR QRF : Pct in range (expecting " + str(100*(1-alpha)*params_qforest["coverage_factor"]) + "%):", in_the_range_qr_qrf / len(y_test) * 100)

# compute and display length of the conformal interval per each test point
length_qr_qrf = y_upper_qr_qrf - y_lower_qr_qrf
print("QR QRF : Average length:", np.mean(length_qr_qrf))

stop = timeit.default_timer()
print('QR QRF: Time: ', stop - start)
# Out:
# QR QRF : Pct in range (expecting 82.08791208791209%): 83.38
# QR QRF : Average length: 1.9404034499163099
# QR QRF: Time:  20.94709387599869

# %% [markdown]
# Define loop for CQR procedure

# %%
def cqr_loop(
      R = 100,
      n_cal = 100,
      n_test = 100,
      alpha = 0.05,
      save_run = False,
      filename = None):

    results = np.array([[0]*5]*R, dtype=float)

    for i in range(R):

        start = timeit.default_timer()

        # calibration and test features
        x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
        x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

        # generate labels
        y_cal = f(x_cal)
        y_test = f(x_test)

        # reshape the features
        x_cal = np.reshape(x_cal,(n_cal, 1))  
        x_test = np.reshape(x_test,(n_test,1))

        # compute the absolute errors on calibration data
        icp.calibrate(x_cal, y_cal)

        # produce predictions for the test set, with confidence equal to significance
        predictions = icp.predict(x_test, significance=alpha)
        y_lower = predictions[:,0]
        y_upper = predictions[:,1]

        # fit QRF base predictor with combined proper train and calibration data
        qrf = helper.QuantileForestRegressorAdapter(model=None,
                                                    fit_params=None,
                                                    quantiles=quantiles,
                                                    params=params_qforest_qrf)
        nc_qrf = RegressorNc(qrf, QuantileRegErrFunc())
        icp_qrf = IcpRegressor(nc_qrf)
        icp_qrf.fit(np.reshape(np.append(x_train, x_cal), (n_train+n_cal, 1)), np.reshape(np.append(y_train, y_cal), (n_train+n_cal, 1)))
        predictions_qrf = qrf.predict(x_test)
        y_lower_qrf = predictions_qrf[:,0]
        y_upper_qrf = predictions_qrf[:,1]

        # compute and display the average coverage
        in_the_range = np.sum((y_test >= y_lower) & (y_test <= y_upper))
        in_the_range_qrf = np.sum((y_test >= y_lower_qrf) & (y_test <= y_upper_qrf))
        print("CQR: Pct in range (expecting " + str(100*(1-alpha)) + "%):", in_the_range / len(y_test) * 100)
        print("QRF: Pct in range (expecting " + str(100*(1-alpha)) + "%):", in_the_range_qrf / len(y_test) * 100)
        results[i][0] = in_the_range / len(y_test) * 100
        results[i][3] = in_the_range_qrf / len(y_test) * 100

        # compute length of the conformal interval per each test point
        length = y_upper - y_lower
        length_qrf = y_upper_qrf - y_lower_qrf

        # compute and display the average length
        print("CQR: Average length:", np.mean(length))
        print("QRF: Average length:", np.mean(length_qrf))
        results[i][1] = np.mean(length)
        results[i][4] = np.mean(length_qrf)

        stop = timeit.default_timer()
        print('CQR: Runtime: ', stop - start)
        results[i][2] = stop - start
    
    results = pd.DataFrame(results,
                           columns = ['CQR Pct in range', 'CQR Avg length', 'Runtime', 'QRF Pct in range', 'QRF Avg length'])
    
    if save_run and (filename is not None):
      results.to_csv(filename, index=False)

    return(results)

# %% [markdown]
# Fit $R=1000$ runs and save results to drive

# %%
np.random.seed(seed)

run = cqr_loop(
      R = R,
      n_cal = n_cal,
      n_test = n_test,
      alpha = alpha,
      save_run = save_run,
      filename = "Experiments Output/toy3_s19_R1000.csv")
# Out:
# CQR: Pct in range (expecting 91.20879120879121%): 88.96
# QRF: Pct in range (expecting 91.20879120879121%): 89.56
# CQR: Average length: 1.9964384269136932
# QRF: Average length: 2.330000908699432
# CQR: Runtime:  20.563138009001705
# CQR: Pct in range (expecting 91.20879120879121%): 92.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQR: Average length: 2.0955594831113253
# QRF: Average length: 2.2504400870115195
# CQR: Runtime:  21.76922945000115
# CQR: Pct in range (expecting 91.20879120879121%): 90.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.62
# CQR: Average length: 2.0351115236132946
# QRF: Average length: 2.2193499892028368
# CQR: Runtime:  21.19914559300014
# CQR: Pct in range (expecting 91.20879120879121%): 91.4
# QRF: Pct in range (expecting 91.20879120879121%): 89.05999999999999
# CQR: Average length: 2.082183205361648
# QRF: Average length: 2.3403520030060907
# CQR: Runtime:  21.90521479399831
# CQR: Pct in range (expecting 91.20879120879121%): 92.44
# QRF: Pct in range (expecting 91.20879120879121%): 91.06
# CQR: Average length: 2.098273675319679
# QRF: Average length: 2.3418269866068813
# CQR: Runtime:  21.682630234001408
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.0573182033815938
# QRF: Average length: 2.2878049708956407
# CQR: Runtime:  20.715680006000184
# CQR: Pct in range (expecting 91.20879120879121%): 90.42
# QRF: Pct in range (expecting 91.20879120879121%): 88.98
# CQR: Average length: 2.0500370708128286
# QRF: Average length: 2.1992905953799133
# CQR: Runtime:  20.690623927999695
# CQR: Pct in range (expecting 91.20879120879121%): 90.92
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.0581684476024695
# QRF: Average length: 2.277280269387135
# CQR: Runtime:  21.9290669539987
# CQR: Pct in range (expecting 91.20879120879121%): 88.92
# QRF: Pct in range (expecting 91.20879120879121%): 88.88000000000001
# CQR: Average length: 2.013161523293062
# QRF: Average length: 2.2161999276741002
# CQR: Runtime:  20.678331471001
# CQR: Pct in range (expecting 91.20879120879121%): 90.03999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.52
# CQR: Average length: 2.037357466548256
# QRF: Average length: 2.2606991640906076
# CQR: Runtime:  20.622435752000456
# CQR: Pct in range (expecting 91.20879120879121%): 91.88
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.06869929336444
# QRF: Average length: 2.3380905002606647
# CQR: Runtime:  20.6572079510006
# CQR: Pct in range (expecting 91.20879120879121%): 90.5
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.0644626125691983
# QRF: Average length: 2.187375146667371
# CQR: Runtime:  20.800400454998453
# CQR: Pct in range (expecting 91.20879120879121%): 89.7
# QRF: Pct in range (expecting 91.20879120879121%): 89.14
# CQR: Average length: 2.0229806977368647
# QRF: Average length: 2.242886734856305
# CQR: Runtime:  21.961846254002012
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.068645120991047
# QRF: Average length: 2.240814908633844
# CQR: Runtime:  20.61835448599959
# CQR: Pct in range (expecting 91.20879120879121%): 88.26
# QRF: Pct in range (expecting 91.20879120879121%): 88.0
# CQR: Average length: 2.0091974718439034
# QRF: Average length: 2.183442896532211
# CQR: Runtime:  20.6686196979972
# CQR: Pct in range (expecting 91.20879120879121%): 92.16
# QRF: Pct in range (expecting 91.20879120879121%): 90.52
# CQR: Average length: 2.0620294158211703
# QRF: Average length: 2.2706780168084704
# CQR: Runtime:  20.580399903003126
# CQR: Pct in range (expecting 91.20879120879121%): 93.36
# QRF: Pct in range (expecting 91.20879120879121%): 90.5
# CQR: Average length: 2.1079800215519833
# QRF: Average length: 2.283680897236918
# CQR: Runtime:  21.952414105999196
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# CQR: Average length: 2.0616548726030737
# QRF: Average length: 2.3123597174546195
# CQR: Runtime:  20.65412343799835
# CQR: Pct in range (expecting 91.20879120879121%): 91.46
# QRF: Pct in range (expecting 91.20879120879121%): 89.75999999999999
# CQR: Average length: 2.0703555171693333
# QRF: Average length: 2.305068766768777
# CQR: Runtime:  20.608321578998584
# CQR: Pct in range (expecting 91.20879120879121%): 90.84
# QRF: Pct in range (expecting 91.20879120879121%): 89.78
# CQR: Average length: 2.057725217665132
# QRF: Average length: 2.1678685126012853
# CQR: Runtime:  20.67160170599891
# CQR: Pct in range (expecting 91.20879120879121%): 90.84
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.045362887396092
# QRF: Average length: 2.2518351599331674
# CQR: Runtime:  21.9992270570001
# CQR: Pct in range (expecting 91.20879120879121%): 90.98
# QRF: Pct in range (expecting 91.20879120879121%): 89.52
# CQR: Average length: 2.0457248668755734
# QRF: Average length: 2.6198001083068134
# CQR: Runtime:  20.658276915997703
# CQR: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.18
# CQR: Average length: 2.02890510303388
# QRF: Average length: 2.3692790150158998
# CQR: Runtime:  20.7283511789974
# CQR: Pct in range (expecting 91.20879120879121%): 94.19999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 91.2
# CQR: Average length: 2.1793727142552264
# QRF: Average length: 2.386747326105864
# CQR: Runtime:  20.695890622999286
# CQR: Pct in range (expecting 91.20879120879121%): 93.04
# QRF: Pct in range (expecting 91.20879120879121%): 91.5
# CQR: Average length: 2.1084020245996222
# QRF: Average length: 2.3176774491801035
# CQR: Runtime:  20.779312246999325
# CQR: Pct in range (expecting 91.20879120879121%): 91.16
# QRF: Pct in range (expecting 91.20879120879121%): 89.86
# CQR: Average length: 2.062359659880283
# QRF: Average length: 2.2138608360581604
# CQR: Runtime:  22.077096199998778
# CQR: Pct in range (expecting 91.20879120879121%): 92.88
# QRF: Pct in range (expecting 91.20879120879121%): 91.02
# CQR: Average length: 2.0995046208472226
# QRF: Average length: 2.27069421867201
# CQR: Runtime:  20.73508522300108
# CQR: Pct in range (expecting 91.20879120879121%): 89.82
# QRF: Pct in range (expecting 91.20879120879121%): 89.66
# CQR: Average length: 2.022895507648642
# QRF: Average length: 2.2660979181387093
# CQR: Runtime:  20.695589208000456
# CQR: Pct in range (expecting 91.20879120879121%): 91.92
# QRF: Pct in range (expecting 91.20879120879121%): 90.52
# CQR: Average length: 2.0787823377330934
# QRF: Average length: 2.3334305677011953
# CQR: Runtime:  20.742134505999275
# CQR: Pct in range (expecting 91.20879120879121%): 91.72
# QRF: Pct in range (expecting 91.20879120879121%): 90.7
# CQR: Average length: 2.0531290900451546
# QRF: Average length: 2.2511162878701567
# CQR: Runtime:  22.058117011998547
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 90.98
# CQR: Average length: 2.0481174894876473
# QRF: Average length: 2.2509082282995942
# CQR: Runtime:  20.61785620700175
# CQR: Pct in range (expecting 91.20879120879121%): 89.52
# QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR: Average length: 2.0010560913252435
# QRF: Average length: 2.2074372154022908
# CQR: Runtime:  20.701506265999342
# CQR: Pct in range (expecting 91.20879120879121%): 91.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.05999999999999
# CQR: Average length: 2.0532485687489412
# QRF: Average length: 2.242646194005372
# CQR: Runtime:  20.65575366899793
# CQR: Pct in range (expecting 91.20879120879121%): 89.78
# QRF: Pct in range (expecting 91.20879120879121%): 89.62
# CQR: Average length: 2.012731317465324
# QRF: Average length: 2.2225289904757237
# CQR: Runtime:  21.916815590000624
# CQR: Pct in range (expecting 91.20879120879121%): 91.18
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.0362347082576773
# QRF: Average length: 2.2874519325915093
# CQR: Runtime:  20.708520570002293
# CQR: Pct in range (expecting 91.20879120879121%): 91.75999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.02
# CQR: Average length: 2.076099920287136
# QRF: Average length: 2.340645648452669
# CQR: Runtime:  20.639377147999767
# CQR: Pct in range (expecting 91.20879120879121%): 91.36
# QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR: Average length: 2.0620766737687632
# QRF: Average length: 2.2412830996125352
# CQR: Runtime:  20.657913278002525
# CQR: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.44
# CQR: Average length: 2.0737989649737725
# QRF: Average length: 2.3038788969377557
# CQR: Runtime:  21.657007017998694
# CQR: Pct in range (expecting 91.20879120879121%): 92.02
# QRF: Pct in range (expecting 91.20879120879121%): 90.28
# CQR: Average length: 2.086315388799494
# QRF: Average length: 2.322060561640213
# CQR: Runtime:  20.98053405799874
# CQR: Pct in range (expecting 91.20879120879121%): 90.08
# QRF: Pct in range (expecting 91.20879120879121%): 89.60000000000001
# CQR: Average length: 2.032965557978177
# QRF: Average length: 2.242726279942758
# CQR: Runtime:  20.70923277699694
# CQR: Pct in range (expecting 91.20879120879121%): 90.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.34
# CQR: Average length: 2.045539677807864
# QRF: Average length: 2.248868660708768
# CQR: Runtime:  20.732753975000378
# CQR: Pct in range (expecting 91.20879120879121%): 92.08
# QRF: Pct in range (expecting 91.20879120879121%): 90.44
# CQR: Average length: 2.0873291319041694
# QRF: Average length: 2.2490619151215063
# CQR: Runtime:  20.68057811199833
# CQR: Pct in range (expecting 91.20879120879121%): 90.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.4
# CQR: Average length: 2.0424249276284354
# QRF: Average length: 2.19813959037312
# CQR: Runtime:  21.967584244001046
# CQR: Pct in range (expecting 91.20879120879121%): 90.4
# QRF: Pct in range (expecting 91.20879120879121%): 89.36
# CQR: Average length: 2.06472673077466
# QRF: Average length: 2.214792925225824
# CQR: Runtime:  20.69173908599987
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.75999999999999
# CQR: Average length: 2.052999940442908
# QRF: Average length: 2.2850215996112055
# CQR: Runtime:  20.656065899001987
# CQR: Pct in range (expecting 91.20879120879121%): 90.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.48
# CQR: Average length: 2.034849660917047
# QRF: Average length: 2.3122600377860327
# CQR: Runtime:  20.611620521001896
# CQR: Pct in range (expecting 91.20879120879121%): 91.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# CQR: Average length: 2.07130112139629
# QRF: Average length: 2.2856203382007254
# CQR: Runtime:  21.955955618999724
# CQR: Pct in range (expecting 91.20879120879121%): 90.02
# QRF: Pct in range (expecting 91.20879120879121%): 89.22
# CQR: Average length: 2.050303989778869
# QRF: Average length: 2.672455647873664
# CQR: Runtime:  20.579443155998888
# CQR: Pct in range (expecting 91.20879120879121%): 90.96
# QRF: Pct in range (expecting 91.20879120879121%): 89.74
# CQR: Average length: 2.0772751822993523
# QRF: Average length: 2.243119742390069
# CQR: Runtime:  20.583133306998207
# CQR: Pct in range (expecting 91.20879120879121%): 90.5
# QRF: Pct in range (expecting 91.20879120879121%): 89.08
# CQR: Average length: 2.064847364794794
# QRF: Average length: 2.3142939815602412
# CQR: Runtime:  20.559526100998482
# CQR: Pct in range (expecting 91.20879120879121%): 90.06
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.012588155757472
# QRF: Average length: 2.1960780919338223
# CQR: Runtime:  21.830746687999635
# CQR: Pct in range (expecting 91.20879120879121%): 90.96
# QRF: Pct in range (expecting 91.20879120879121%): 89.66
# CQR: Average length: 2.087394052469609
# QRF: Average length: 2.308541310316662
# CQR: Runtime:  20.65969679399859
# CQR: Pct in range (expecting 91.20879120879121%): 91.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.0780810812277952
# QRF: Average length: 2.3186933830335
# CQR: Runtime:  20.635582584000076
# CQR: Pct in range (expecting 91.20879120879121%): 91.58
# QRF: Pct in range (expecting 91.20879120879121%): 90.18
# CQR: Average length: 2.0598364576033132
# QRF: Average length: 2.202517014455937
# CQR: Runtime:  20.5899820750019
# CQR: Pct in range (expecting 91.20879120879121%): 90.62
# QRF: Pct in range (expecting 91.20879120879121%): 90.34
# CQR: Average length: 2.0409621750631968
# QRF: Average length: 2.310662302787871
# CQR: Runtime:  20.632004671002505
# CQR: Pct in range (expecting 91.20879120879121%): 91.06
# QRF: Pct in range (expecting 91.20879120879121%): 89.72
# CQR: Average length: 2.0532412878051334
# QRF: Average length: 2.2490510200334617
# CQR: Runtime:  21.95479112099929
# CQR: Pct in range (expecting 91.20879120879121%): 92.58
# QRF: Pct in range (expecting 91.20879120879121%): 90.86
# CQR: Average length: 2.0996398380881387
# QRF: Average length: 2.263343732866962
# CQR: Runtime:  20.60586681100176
# CQR: Pct in range (expecting 91.20879120879121%): 89.9
# QRF: Pct in range (expecting 91.20879120879121%): 89.48
# CQR: Average length: 2.0224608729843974
# QRF: Average length: 2.2195745328646095
# CQR: Runtime:  20.56899607000014
# CQR: Pct in range (expecting 91.20879120879121%): 92.2
# QRF: Pct in range (expecting 91.20879120879121%): 90.32
# CQR: Average length: 2.072573918431823
# QRF: Average length: 2.2700540003517444
# CQR: Runtime:  20.626379400997394
# CQR: Pct in range (expecting 91.20879120879121%): 91.3
# QRF: Pct in range (expecting 91.20879120879121%): 90.92
# CQR: Average length: 2.0612901317648484
# QRF: Average length: 2.240527779817936
# CQR: Runtime:  21.871407103997626
# CQR: Pct in range (expecting 91.20879120879121%): 90.94
# QRF: Pct in range (expecting 91.20879120879121%): 89.86
# CQR: Average length: 2.029791315790721
# QRF: Average length: 2.2847401779711976
# CQR: Runtime:  20.623128710001765
# CQR: Pct in range (expecting 91.20879120879121%): 90.66
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.016854101540232
# QRF: Average length: 2.220574998400608
# CQR: Runtime:  20.535646011998324
# CQR: Pct in range (expecting 91.20879120879121%): 90.46
# QRF: Pct in range (expecting 91.20879120879121%): 89.7
# CQR: Average length: 2.0557314572672305
# QRF: Average length: 2.2643936898136356
# CQR: Runtime:  20.532643663998897
# CQR: Pct in range (expecting 91.20879120879121%): 92.74
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.0749903616784864
# QRF: Average length: 2.5611091231996115
# CQR: Runtime:  21.921969515002274
# CQR: Pct in range (expecting 91.20879120879121%): 91.47999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.06
# CQR: Average length: 2.0544519070350193
# QRF: Average length: 2.1738051004939063
# CQR: Runtime:  20.602004552001745
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 89.46
# CQR: Average length: 2.0579738255085367
# QRF: Average length: 2.466555484507371
# CQR: Runtime:  20.621605554999405
# CQR: Pct in range (expecting 91.20879120879121%): 90.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.12
# CQR: Average length: 2.0645499824960116
# QRF: Average length: 2.195321713908272
# CQR: Runtime:  20.55971642700024
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQR: Average length: 2.0356728025305637
# QRF: Average length: 2.2899960689863814
# CQR: Runtime:  20.694988585997635
# CQR: Pct in range (expecting 91.20879120879121%): 90.24
# QRF: Pct in range (expecting 91.20879120879121%): 89.38000000000001
# CQR: Average length: 2.0326973429216095
# QRF: Average length: 2.1760867704989644
# CQR: Runtime:  21.774992671998916
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.66
# CQR: Average length: 2.06036187545313
# QRF: Average length: 2.2513864496069895
# CQR: Runtime:  20.620219032000023
# CQR: Pct in range (expecting 91.20879120879121%): 91.25999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.94
# CQR: Average length: 2.043684177212275
# QRF: Average length: 2.3249564966582095
# CQR: Runtime:  20.679121927998494
# CQR: Pct in range (expecting 91.20879120879121%): 91.8
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.0767610829975944
# QRF: Average length: 2.3425015225167924
# CQR: Runtime:  20.65891586900034
# CQR: Pct in range (expecting 91.20879120879121%): 92.30000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.22
# CQR: Average length: 2.08662075304118
# QRF: Average length: 2.352441677093883
# CQR: Runtime:  22.346515920002275
# CQR: Pct in range (expecting 91.20879120879121%): 91.4
# QRF: Pct in range (expecting 91.20879120879121%): 90.82000000000001
# CQR: Average length: 2.0422918168253283
# QRF: Average length: 2.382403895850268
# CQR: Runtime:  20.954571510999813
# CQR: Pct in range (expecting 91.20879120879121%): 89.64
# QRF: Pct in range (expecting 91.20879120879121%): 89.60000000000001
# CQR: Average length: 2.0145890313471844
# QRF: Average length: 2.280918930420489
# CQR: Runtime:  20.654025115996774
# CQR: Pct in range (expecting 91.20879120879121%): 90.12
# QRF: Pct in range (expecting 91.20879120879121%): 89.02
# CQR: Average length: 2.0150057632937646
# QRF: Average length: 2.2139190571391003
# CQR: Runtime:  20.70625437200215
# CQR: Pct in range (expecting 91.20879120879121%): 90.44
# QRF: Pct in range (expecting 91.20879120879121%): 89.53999999999999
# CQR: Average length: 2.045600654501875
# QRF: Average length: 2.2169923356786283
# CQR: Runtime:  22.00533515400093
# CQR: Pct in range (expecting 91.20879120879121%): 89.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.22
# CQR: Average length: 2.0040131036558058
# QRF: Average length: 2.2495610949778793
# CQR: Runtime:  20.712865168999997
# CQR: Pct in range (expecting 91.20879120879121%): 90.92
# QRF: Pct in range (expecting 91.20879120879121%): 90.12
# CQR: Average length: 2.071828831986451
# QRF: Average length: 2.344150738442582
# CQR: Runtime:  20.621896407999884
# CQR: Pct in range (expecting 91.20879120879121%): 89.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.74
# CQR: Average length: 2.0224055649269452
# QRF: Average length: 2.1993808160137354
# CQR: Runtime:  20.60609300500073
# CQR: Pct in range (expecting 91.20879120879121%): 91.88
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.071209361044272
# QRF: Average length: 2.2121324056201366
# CQR: Runtime:  22.047987083999033
# CQR: Pct in range (expecting 91.20879120879121%): 91.34
# QRF: Pct in range (expecting 91.20879120879121%): 90.02
# CQR: Average length: 2.0428928128095336
# QRF: Average length: 2.1881022041762104
# CQR: Runtime:  20.74116098200102
# CQR: Pct in range (expecting 91.20879120879121%): 91.96
# QRF: Pct in range (expecting 91.20879120879121%): 89.92
# CQR: Average length: 2.066505240863485
# QRF: Average length: 2.186636628562754
# CQR: Runtime:  20.680091148002248
# CQR: Pct in range (expecting 91.20879120879121%): 90.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.28
# CQR: Average length: 2.036885831882655
# QRF: Average length: 2.3005933021016114
# CQR: Runtime:  20.699618921000365
# CQR: Pct in range (expecting 91.20879120879121%): 89.5
# QRF: Pct in range (expecting 91.20879120879121%): 88.72
# CQR: Average length: 2.0406076398755775
# QRF: Average length: 2.280717766407739
# CQR: Runtime:  22.00815533900095
# CQR: Pct in range (expecting 91.20879120879121%): 91.2
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.032087296445741
# QRF: Average length: 2.200960542630717
# CQR: Runtime:  20.73930613000266
# CQR: Pct in range (expecting 91.20879120879121%): 92.04
# QRF: Pct in range (expecting 91.20879120879121%): 89.96
# CQR: Average length: 2.0797252404513262
# QRF: Average length: 2.263243428164405
# CQR: Runtime:  20.757333172998187
# CQR: Pct in range (expecting 91.20879120879121%): 92.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# CQR: Average length: 2.0900568081088
# QRF: Average length: 2.4119289728960327
# CQR: Runtime:  20.701369471000362
# CQR: Pct in range (expecting 91.20879120879121%): 89.3
# QRF: Pct in range (expecting 91.20879120879121%): 89.02
# CQR: Average length: 2.0201198154101383
# QRF: Average length: 2.2077548524110613
# CQR: Runtime:  21.17924945499908
# CQR: Pct in range (expecting 91.20879120879121%): 90.84
# QRF: Pct in range (expecting 91.20879120879121%): 89.46
# CQR: Average length: 2.012863934119083
# QRF: Average length: 2.1345534601779104
# CQR: Runtime:  21.671873125000275
# CQR: Pct in range (expecting 91.20879120879121%): 90.46
# QRF: Pct in range (expecting 91.20879120879121%): 89.72
# CQR: Average length: 2.0532439858281015
# QRF: Average length: 2.2134740294133377
# CQR: Runtime:  20.653212326000357
# CQR: Pct in range (expecting 91.20879120879121%): 91.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.62
# CQR: Average length: 2.058471548565015
# QRF: Average length: 2.2058168082081835
# CQR: Runtime:  20.717196718000196
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.34
# CQR: Average length: 2.02928120282333
# QRF: Average length: 2.215835360447806
# CQR: Runtime:  20.73259783100002
# CQR: Pct in range (expecting 91.20879120879121%): 91.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.42
# CQR: Average length: 2.0629971856000533
# QRF: Average length: 2.331819452056424
# CQR: Runtime:  22.012974035002117
# CQR: Pct in range (expecting 91.20879120879121%): 91.22
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.0557361371276506
# QRF: Average length: 2.2423506083388216
# CQR: Runtime:  20.71420272999967
# CQR: Pct in range (expecting 91.20879120879121%): 91.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.96
# CQR: Average length: 2.061890831473078
# QRF: Average length: 2.2175643007974557
# CQR: Runtime:  20.713746274002915
# CQR: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.0370234974473607
# QRF: Average length: 2.194798517107625
# CQR: Runtime:  20.626259538999875
# CQR: Pct in range (expecting 91.20879120879121%): 89.8
# QRF: Pct in range (expecting 91.20879120879121%): 89.78
# CQR: Average length: 2.047115177015349
# QRF: Average length: 2.2969751019144895
# CQR: Runtime:  22.04494007500034
# CQR: Pct in range (expecting 91.20879120879121%): 91.78
# QRF: Pct in range (expecting 91.20879120879121%): 90.5
# CQR: Average length: 2.0574360347597977
# QRF: Average length: 2.228646075314342
# CQR: Runtime:  20.69433364899669
# CQR: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.74
# CQR: Average length: 2.061181801450588
# QRF: Average length: 2.3070189127891085
# CQR: Runtime:  20.69244750800135
# CQR: Pct in range (expecting 91.20879120879121%): 91.34
# QRF: Pct in range (expecting 91.20879120879121%): 90.22
# CQR: Average length: 2.0488585805751964
# QRF: Average length: 2.269316899918468
# CQR: Runtime:  20.689816997997696
# CQR: Pct in range (expecting 91.20879120879121%): 92.52
# QRF: Pct in range (expecting 91.20879120879121%): 90.34
# CQR: Average length: 2.0549305727799396
# QRF: Average length: 2.2853816770310513
# CQR: Runtime:  21.928024019001896
# CQR: Pct in range (expecting 91.20879120879121%): 90.34
# QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR: Average length: 2.0247720413353827
# QRF: Average length: 2.298142817143452
# CQR: Runtime:  20.64303594300145
# CQR: Pct in range (expecting 91.20879120879121%): 90.72
# QRF: Pct in range (expecting 91.20879120879121%): 89.0
# CQR: Average length: 2.0245197472002148
# QRF: Average length: 2.2352365007321415
# CQR: Runtime:  20.754454717000044
# CQR: Pct in range (expecting 91.20879120879121%): 91.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.44
# CQR: Average length: 2.046773661329467
# QRF: Average length: 2.230202474414041
# CQR: Runtime:  20.730843108001864
# CQR: Pct in range (expecting 91.20879120879121%): 91.42
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.0612605903320627
# QRF: Average length: 2.2818534404017576
# CQR: Runtime:  21.886810643998615
# CQR: Pct in range (expecting 91.20879120879121%): 93.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# CQR: Average length: 2.1343366115982683
# QRF: Average length: 2.3593966714870347
# CQR: Runtime:  20.635779130003357
# CQR: Pct in range (expecting 91.20879120879121%): 90.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.53999999999999
# CQR: Average length: 2.0369544996879423
# QRF: Average length: 2.225423714519049
# CQR: Runtime:  20.653870062997157
# CQR: Pct in range (expecting 91.20879120879121%): 89.44
# QRF: Pct in range (expecting 91.20879120879121%): 88.58
# CQR: Average length: 2.020005457266053
# QRF: Average length: 2.2549583466071264
# CQR: Runtime:  20.66505462799978
# CQR: Pct in range (expecting 91.20879120879121%): 90.5
# QRF: Pct in range (expecting 91.20879120879121%): 89.98
# CQR: Average length: 2.070628435781958
# QRF: Average length: 2.2844394092271156
# CQR: Runtime:  21.91183587100022
# CQR: Pct in range (expecting 91.20879120879121%): 91.02
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.0525209229341113
# QRF: Average length: 2.2465971965852907
# CQR: Runtime:  20.569017374000396
# CQR: Pct in range (expecting 91.20879120879121%): 91.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.22
# CQR: Average length: 2.071966994608796
# QRF: Average length: 2.4073038398263518
# CQR: Runtime:  20.605204669998784
# CQR: Pct in range (expecting 91.20879120879121%): 90.32
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.0250886668440984
# QRF: Average length: 2.26261617371477
# CQR: Runtime:  20.676257365998026
# CQR: Pct in range (expecting 91.20879120879121%): 91.88
# QRF: Pct in range (expecting 91.20879120879121%): 89.94
# CQR: Average length: 2.0714564104286257
# QRF: Average length: 2.381071861072764
# CQR: Runtime:  21.90710358299839
# CQR: Pct in range (expecting 91.20879120879121%): 91.24
# QRF: Pct in range (expecting 91.20879120879121%): 90.52
# CQR: Average length: 2.052409052287278
# QRF: Average length: 2.2366266294977097
# CQR: Runtime:  20.679230413003097
# CQR: Pct in range (expecting 91.20879120879121%): 91.78
# QRF: Pct in range (expecting 91.20879120879121%): 91.06
# CQR: Average length: 2.099711725767665
# QRF: Average length: 2.267294322131614
# CQR: Runtime:  20.6560599129989
# CQR: Pct in range (expecting 91.20879120879121%): 92.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.82000000000001
# CQR: Average length: 2.072623428502163
# QRF: Average length: 2.3289323800680592
# CQR: Runtime:  20.62581041500016
# CQR: Pct in range (expecting 91.20879120879121%): 90.16
# QRF: Pct in range (expecting 91.20879120879121%): 89.22
# CQR: Average length: 2.0261170021378194
# QRF: Average length: 2.2399685443077817
# CQR: Runtime:  21.91026271499868
# CQR: Pct in range (expecting 91.20879120879121%): 92.47999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.099247160570589
# QRF: Average length: 2.331683808338011
# CQR: Runtime:  20.65298773500035
# CQR: Pct in range (expecting 91.20879120879121%): 91.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.38000000000001
# CQR: Average length: 2.090536795198606
# QRF: Average length: 2.2667259791528234
# CQR: Runtime:  20.56115623900041
# CQR: Pct in range (expecting 91.20879120879121%): 92.24
# QRF: Pct in range (expecting 91.20879120879121%): 90.03999999999999
# CQR: Average length: 2.081477386041197
# QRF: Average length: 2.2618346075507128
# CQR: Runtime:  20.624676444000215
# CQR: Pct in range (expecting 91.20879120879121%): 91.14
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.058358625774478
# QRF: Average length: 2.217823152394924
# CQR: Runtime:  21.959300477999932
# CQR: Pct in range (expecting 91.20879120879121%): 90.18
# QRF: Pct in range (expecting 91.20879120879121%): 89.5
# CQR: Average length: 2.0425512940365302
# QRF: Average length: 2.217366325270186
# CQR: Runtime:  20.732063134000782
# CQR: Pct in range (expecting 91.20879120879121%): 92.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.98
# CQR: Average length: 2.1404317129019916
# QRF: Average length: 2.341613252155946
# CQR: Runtime:  20.590483550997305
# CQR: Pct in range (expecting 91.20879120879121%): 92.24
# QRF: Pct in range (expecting 91.20879120879121%): 90.8
# CQR: Average length: 2.0649781319762615
# QRF: Average length: 2.229891417332158
# CQR: Runtime:  20.663666603999445
# CQR: Pct in range (expecting 91.20879120879121%): 89.96
# QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR: Average length: 2.006350956275817
# QRF: Average length: 2.2122358940597624
# CQR: Runtime:  21.865105434000725
# CQR: Pct in range (expecting 91.20879120879121%): 91.46
# QRF: Pct in range (expecting 91.20879120879121%): 90.92
# CQR: Average length: 2.042563757839588
# QRF: Average length: 2.206890961269266
# CQR: Runtime:  20.72377619799954
# CQR: Pct in range (expecting 91.20879120879121%): 90.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.0334784896951734
# QRF: Average length: 2.1726822252443476
# CQR: Runtime:  20.61450373199841
# CQR: Pct in range (expecting 91.20879120879121%): 90.72
# QRF: Pct in range (expecting 91.20879120879121%): 89.24
# CQR: Average length: 2.0385473747495313
# QRF: Average length: 2.3260883520434126
# CQR: Runtime:  20.718963489001908
# CQR: Pct in range (expecting 91.20879120879121%): 91.16
# QRF: Pct in range (expecting 91.20879120879121%): 89.18
# CQR: Average length: 2.063798226066265
# QRF: Average length: 2.2023757122323997
# CQR: Runtime:  21.94475248099843
# CQR: Pct in range (expecting 91.20879120879121%): 90.28
# QRF: Pct in range (expecting 91.20879120879121%): 89.46
# CQR: Average length: 2.0416557845612253
# QRF: Average length: 2.2358756663374386
# CQR: Runtime:  20.760215483001957
# CQR: Pct in range (expecting 91.20879120879121%): 91.8
# QRF: Pct in range (expecting 91.20879120879121%): 90.82000000000001
# CQR: Average length: 2.0590892966975507
# QRF: Average length: 2.2617940996122115
# CQR: Runtime:  20.812978187001136
# CQR: Pct in range (expecting 91.20879120879121%): 90.92
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.0627883515790737
# QRF: Average length: 2.2811646831048127
# CQR: Runtime:  20.64535065599921
# CQR: Pct in range (expecting 91.20879120879121%): 89.36
# QRF: Pct in range (expecting 91.20879120879121%): 89.14
# CQR: Average length: 2.0384978414175077
# QRF: Average length: 2.245101505014392
# CQR: Runtime:  21.933057479000126
# CQR: Pct in range (expecting 91.20879120879121%): 90.16
# QRF: Pct in range (expecting 91.20879120879121%): 88.96
# CQR: Average length: 2.016302894850496
# QRF: Average length: 2.185532699848364
# CQR: Runtime:  20.739790845000243
# CQR: Pct in range (expecting 91.20879120879121%): 91.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.0902701544460087
# QRF: Average length: 2.2509747459909346
# CQR: Runtime:  20.6744258050021
# CQR: Pct in range (expecting 91.20879120879121%): 91.46
# QRF: Pct in range (expecting 91.20879120879121%): 90.52
# CQR: Average length: 2.058042801180375
# QRF: Average length: 2.266133139386804
# CQR: Runtime:  20.703419414003292
# CQR: Pct in range (expecting 91.20879120879121%): 93.76
# QRF: Pct in range (expecting 91.20879120879121%): 91.12
# CQR: Average length: 2.137402298655692
# QRF: Average length: 2.6374548208403907
# CQR: Runtime:  21.901592301001074
# CQR: Pct in range (expecting 91.20879120879121%): 92.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 91.32000000000001
# CQR: Average length: 2.0686779691130477
# QRF: Average length: 2.2500744461918303
# CQR: Runtime:  20.6956390919986
# CQR: Pct in range (expecting 91.20879120879121%): 91.94
# QRF: Pct in range (expecting 91.20879120879121%): 90.56
# CQR: Average length: 2.047764481170494
# QRF: Average length: 2.308057170054717
# CQR: Runtime:  20.698086805998173
# CQR: Pct in range (expecting 91.20879120879121%): 92.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 91.02
# CQR: Average length: 2.110845665343204
# QRF: Average length: 2.2221457878545885
# CQR: Runtime:  20.607842171997618
# CQR: Pct in range (expecting 91.20879120879121%): 91.47999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.25999999999999
# CQR: Average length: 2.0474817953429842
# QRF: Average length: 2.2544582067368886
# CQR: Runtime:  21.98048358199958
# CQR: Pct in range (expecting 91.20879120879121%): 90.4
# QRF: Pct in range (expecting 91.20879120879121%): 89.02
# CQR: Average length: 2.060325137368511
# QRF: Average length: 2.236878151164031
# CQR: Runtime:  20.757715484000073
# CQR: Pct in range (expecting 91.20879120879121%): 90.86
# QRF: Pct in range (expecting 91.20879120879121%): 89.46
# CQR: Average length: 2.032406893210582
# QRF: Average length: 2.194932844910014
# CQR: Runtime:  20.707545840999956
# CQR: Pct in range (expecting 91.20879120879121%): 92.06
# QRF: Pct in range (expecting 91.20879120879121%): 89.7
# CQR: Average length: 2.0797674462498557
# QRF: Average length: 2.2388936546861418
# CQR: Runtime:  20.810976110999036
# CQR: Pct in range (expecting 91.20879120879121%): 90.72
# QRF: Pct in range (expecting 91.20879120879121%): 89.9
# CQR: Average length: 2.037724500585772
# QRF: Average length: 2.2307749535060126
# CQR: Runtime:  21.971623295001336
# CQR: Pct in range (expecting 91.20879120879121%): 91.22
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.071508696693067
# QRF: Average length: 2.29515822641397
# CQR: Runtime:  20.695390292999946
# CQR: Pct in range (expecting 91.20879120879121%): 90.72
# QRF: Pct in range (expecting 91.20879120879121%): 88.92
# CQR: Average length: 2.0691011751141293
# QRF: Average length: 2.2262376373444126
# CQR: Runtime:  20.617953631001
# CQR: Pct in range (expecting 91.20879120879121%): 90.78
# QRF: Pct in range (expecting 91.20879120879121%): 89.05999999999999
# CQR: Average length: 2.06661109685433
# QRF: Average length: 2.3550405640917704
# CQR: Runtime:  20.589872690001357
# CQR: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.28
# CQR: Average length: 2.0467891543010306
# QRF: Average length: 2.2508462162632035
# CQR: Runtime:  21.75041694399988
# CQR: Pct in range (expecting 91.20879120879121%): 91.58
# QRF: Pct in range (expecting 91.20879120879121%): 89.56
# CQR: Average length: 2.0802228535722826
# QRF: Average length: 2.25475868467301
# CQR: Runtime:  21.085852711999905
# CQR: Pct in range (expecting 91.20879120879121%): 90.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.36
# CQR: Average length: 2.03827771258338
# QRF: Average length: 2.2414730165988583
# CQR: Runtime:  20.694350793000922
# CQR: Pct in range (expecting 91.20879120879121%): 91.47999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.38000000000001
# CQR: Average length: 2.0492631015303924
# QRF: Average length: 2.267252721151688
# CQR: Runtime:  20.706786261998786
# CQR: Pct in range (expecting 91.20879120879121%): 91.4
# QRF: Pct in range (expecting 91.20879120879121%): 90.24
# CQR: Average length: 2.0843653532367497
# QRF: Average length: 2.2417683360584957
# CQR: Runtime:  21.461455675998877
# CQR: Pct in range (expecting 91.20879120879121%): 92.52
# QRF: Pct in range (expecting 91.20879120879121%): 90.62
# CQR: Average length: 2.085639316054107
# QRF: Average length: 2.285951589662148
# CQR: Runtime:  21.313902709000104
# CQR: Pct in range (expecting 91.20879120879121%): 92.17999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 91.06
# CQR: Average length: 2.0731624329825618
# QRF: Average length: 2.5999997521574523
# CQR: Runtime:  20.665673847997823
# CQR: Pct in range (expecting 91.20879120879121%): 91.46
# QRF: Pct in range (expecting 91.20879120879121%): 90.74
# CQR: Average length: 2.0454968988888043
# QRF: Average length: 2.4226901454625143
# CQR: Runtime:  20.69263213299928
# CQR: Pct in range (expecting 91.20879120879121%): 92.02
# QRF: Pct in range (expecting 91.20879120879121%): 90.68
# CQR: Average length: 2.0648510733097925
# QRF: Average length: 2.246021524836682
# CQR: Runtime:  20.94039138500011
# CQR: Pct in range (expecting 91.20879120879121%): 92.54
# QRF: Pct in range (expecting 91.20879120879121%): 91.2
# CQR: Average length: 2.1030823940704537
# QRF: Average length: 2.3985296605871618
# CQR: Runtime:  21.773326989998168
# CQR: Pct in range (expecting 91.20879120879121%): 91.74
# QRF: Pct in range (expecting 91.20879120879121%): 91.36
# CQR: Average length: 2.05989520406511
# QRF: Average length: 2.222971521120457
# CQR: Runtime:  20.698414787999354
# CQR: Pct in range (expecting 91.20879120879121%): 92.0
# QRF: Pct in range (expecting 91.20879120879121%): 90.12
# CQR: Average length: 2.0717761725050834
# QRF: Average length: 2.294227284034978
# CQR: Runtime:  20.723281213999144
# CQR: Pct in range (expecting 91.20879120879121%): 93.02
# QRF: Pct in range (expecting 91.20879120879121%): 91.08000000000001
# CQR: Average length: 2.1117124397952907
# QRF: Average length: 2.3351421151933462
# CQR: Runtime:  20.722644582998328
# CQR: Pct in range (expecting 91.20879120879121%): 93.30000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 91.02
# CQR: Average length: 2.095234446713714
# QRF: Average length: 2.2757971732854525
# CQR: Runtime:  22.02625528200224
# CQR: Pct in range (expecting 91.20879120879121%): 91.25999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# CQR: Average length: 2.047304362752952
# QRF: Average length: 2.195950616463074
# CQR: Runtime:  20.7084237199997
# CQR: Pct in range (expecting 91.20879120879121%): 90.75999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.055850571608483
# QRF: Average length: 2.2165581968832804
# CQR: Runtime:  20.680023666001944
# CQR: Pct in range (expecting 91.20879120879121%): 89.74
# QRF: Pct in range (expecting 91.20879120879121%): 89.05999999999999
# CQR: Average length: 2.0233396779417765
# QRF: Average length: 2.184230499101809
# CQR: Runtime:  20.697777854999003
# CQR: Pct in range (expecting 91.20879120879121%): 90.42
# QRF: Pct in range (expecting 91.20879120879121%): 89.24
# CQR: Average length: 2.0587087731807636
# QRF: Average length: 2.2984540041288377
# CQR: Runtime:  22.085459280999203
# CQR: Pct in range (expecting 91.20879120879121%): 88.38000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 88.68
# CQR: Average length: 2.0173909891438195
# QRF: Average length: 2.176188337248002
# CQR: Runtime:  20.638113508997776
# CQR: Pct in range (expecting 91.20879120879121%): 91.56
# QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQR: Average length: 2.051763299169053
# QRF: Average length: 2.2323812321012992
# CQR: Runtime:  20.72062316300071
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.036147026094958
# QRF: Average length: 2.2947818689391313
# CQR: Runtime:  20.697305736997805
# CQR: Pct in range (expecting 91.20879120879121%): 91.75999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.042360504581409
# QRF: Average length: 2.221091231425053
# CQR: Runtime:  22.019404585000302
# CQR: Pct in range (expecting 91.20879120879121%): 90.9
# QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR: Average length: 2.081191529170323
# QRF: Average length: 2.2153509327375676
# CQR: Runtime:  20.599561558999994
# CQR: Pct in range (expecting 91.20879120879121%): 91.3
# QRF: Pct in range (expecting 91.20879120879121%): 90.36
# CQR: Average length: 2.0635047495517735
# QRF: Average length: 2.1879411383064533
# CQR: Runtime:  20.7575434950013
# CQR: Pct in range (expecting 91.20879120879121%): 91.3
# QRF: Pct in range (expecting 91.20879120879121%): 90.4
# CQR: Average length: 2.0375335797726364
# QRF: Average length: 2.1820637822746716
# CQR: Runtime:  20.67936703599844
# CQR: Pct in range (expecting 91.20879120879121%): 90.7
# QRF: Pct in range (expecting 91.20879120879121%): 89.74
# CQR: Average length: 2.0218270146169406
# QRF: Average length: 2.239707374012772
# CQR: Runtime:  22.008863813000062
# CQR: Pct in range (expecting 91.20879120879121%): 92.36
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.096503901433597
# QRF: Average length: 2.3611261666480154
# CQR: Runtime:  20.690463661998365
# CQR: Pct in range (expecting 91.20879120879121%): 92.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQR: Average length: 2.0938314839604377
# QRF: Average length: 2.3367333051152355
# CQR: Runtime:  20.777108125999803
# CQR: Pct in range (expecting 91.20879120879121%): 91.47999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.98
# CQR: Average length: 2.060805674377085
# QRF: Average length: 2.228959151830128
# CQR: Runtime:  20.68232408900076
# CQR: Pct in range (expecting 91.20879120879121%): 91.24
# QRF: Pct in range (expecting 91.20879120879121%): 90.24
# CQR: Average length: 2.0618706503922946
# QRF: Average length: 2.450289690989402
# CQR: Runtime:  22.06886624300023
# CQR: Pct in range (expecting 91.20879120879121%): 90.48
# QRF: Pct in range (expecting 91.20879120879121%): 88.96
# CQR: Average length: 2.0320882010580714
# QRF: Average length: 2.2485219558584446
# CQR: Runtime:  20.70846620899829
# CQR: Pct in range (expecting 91.20879120879121%): 88.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 88.8
# CQR: Average length: 2.020380766926951
# QRF: Average length: 2.2077855470399865
# CQR: Runtime:  20.712190137001016
# CQR: Pct in range (expecting 91.20879120879121%): 91.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.4
# CQR: Average length: 2.0828345281085707
# QRF: Average length: 2.3451078772609524
# CQR: Runtime:  20.775036959003046
# CQR: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.64
# CQR: Average length: 2.0420270029669294
# QRF: Average length: 2.7039834955533095
# CQR: Runtime:  22.212562426997465
# CQR: Pct in range (expecting 91.20879120879121%): 91.86
# QRF: Pct in range (expecting 91.20879120879121%): 90.48
# CQR: Average length: 2.0678597657942075
# QRF: Average length: 2.2957143929138097
# CQR: Runtime:  20.752285596001457
# CQR: Pct in range (expecting 91.20879120879121%): 91.64
# QRF: Pct in range (expecting 91.20879120879121%): 90.22
# CQR: Average length: 2.0818505641625737
# QRF: Average length: 2.2569217189021185
# CQR: Runtime:  20.72833229599928
# CQR: Pct in range (expecting 91.20879120879121%): 89.62
# QRF: Pct in range (expecting 91.20879120879121%): 88.3
# CQR: Average length: 2.049303400683609
# QRF: Average length: 2.259185660880627
# CQR: Runtime:  20.869572180999967
# CQR: Pct in range (expecting 91.20879120879121%): 91.0
# QRF: Pct in range (expecting 91.20879120879121%): 88.82
# CQR: Average length: 2.0653524149696616
# QRF: Average length: 2.255251018453797
# CQR: Runtime:  22.275772362998396
# CQR: Pct in range (expecting 91.20879120879121%): 91.9
# QRF: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# CQR: Average length: 2.078915971102907
# QRF: Average length: 2.340981640853457
# CQR: Runtime:  20.783461480998085
# CQR: Pct in range (expecting 91.20879120879121%): 91.56
# QRF: Pct in range (expecting 91.20879120879121%): 91.3
# CQR: Average length: 2.0475921895635163
# QRF: Average length: 2.2511028421926094
# CQR: Runtime:  20.913169812996784
# CQR: Pct in range (expecting 91.20879120879121%): 89.0
# QRF: Pct in range (expecting 91.20879120879121%): 89.2
# CQR: Average length: 2.020561968654197
# QRF: Average length: 2.1631599909267467
# CQR: Runtime:  20.79307434799921
# CQR: Pct in range (expecting 91.20879120879121%): 92.42
# QRF: Pct in range (expecting 91.20879120879121%): 91.0
# CQR: Average length: 2.0823909433147776
# QRF: Average length: 2.211829643680882
# CQR: Runtime:  22.053961353001796
# CQR: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.10000000000001
# CQR: Average length: 2.0787116045406293
# QRF: Average length: 2.2523215436957806
# CQR: Runtime:  20.82070430299791
# CQR: Pct in range (expecting 91.20879120879121%): 90.74
# QRF: Pct in range (expecting 91.20879120879121%): 89.46
# CQR: Average length: 2.068871309059312
# QRF: Average length: 2.2354984651341234
# CQR: Runtime:  20.767771774997527
# CQR: Pct in range (expecting 91.20879120879121%): 91.5
# QRF: Pct in range (expecting 91.20879120879121%): 90.64
# CQR: Average length: 2.077504956766191
# QRF: Average length: 2.311778771958911
# CQR: Runtime:  20.690864340998814
# CQR: Pct in range (expecting 91.20879120879121%): 91.5
# QRF: Pct in range (expecting 91.20879120879121%): 90.66
# CQR: Average length: 2.0334420573108667
# QRF: Average length: 2.235825750071018
# CQR: Runtime:  22.12616954400073
# CQR: Pct in range (expecting 91.20879120879121%): 90.48
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.057821556755008
# QRF: Average length: 2.210493059760783
# CQR: Runtime:  20.821014886998455
# CQR: Pct in range (expecting 91.20879120879121%): 92.60000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.86
# CQR: Average length: 2.078041706309855
# QRF: Average length: 2.350711803329604
# CQR: Runtime:  20.81172184300158
# CQR: Pct in range (expecting 91.20879120879121%): 91.72
# QRF: Pct in range (expecting 91.20879120879121%): 90.74
# CQR: Average length: 2.0742553441970393
# QRF: Average length: 2.259992025658951
# CQR: Runtime:  20.7760931490011
# CQR: Pct in range (expecting 91.20879120879121%): 91.52
# QRF: Pct in range (expecting 91.20879120879121%): 90.64
# CQR: Average length: 2.0422943143030716
# QRF: Average length: 2.2268772298445625
# CQR: Runtime:  21.94989765400169
# CQR: Pct in range (expecting 91.20879120879121%): 91.75999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.36
# CQR: Average length: 2.064723399053502
# QRF: Average length: 2.3500264536640905
# CQR: Runtime:  20.683197228001518
# CQR: Pct in range (expecting 91.20879120879121%): 92.22
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.080127333149365
# QRF: Average length: 2.2944538335030957
# CQR: Runtime:  20.725020910998865
# CQR: Pct in range (expecting 91.20879120879121%): 90.34
# QRF: Pct in range (expecting 91.20879120879121%): 89.44
# CQR: Average length: 2.021004654746104
# QRF: Average length: 2.165133740927686
# CQR: Runtime:  20.71372390400211
# CQR: Pct in range (expecting 91.20879120879121%): 91.44
# QRF: Pct in range (expecting 91.20879120879121%): 90.7
# CQR: Average length: 2.025035506072684
# QRF: Average length: 2.2161338455891006
# CQR: Runtime:  22.053744757002278
# CQR: Pct in range (expecting 91.20879120879121%): 90.28
# QRF: Pct in range (expecting 91.20879120879121%): 89.34
# CQR: Average length: 2.049305857274797
# QRF: Average length: 2.198049180181087
# CQR: Runtime:  20.671319932996994
# CQR: Pct in range (expecting 91.20879120879121%): 93.02
# QRF: Pct in range (expecting 91.20879120879121%): 91.34
# CQR: Average length: 2.0998278022101773
# QRF: Average length: 2.29723091155668
# CQR: Runtime:  20.68442302299809
# CQR: Pct in range (expecting 91.20879120879121%): 91.42
# QRF: Pct in range (expecting 91.20879120879121%): 89.5
# CQR: Average length: 2.070691673783624
# QRF: Average length: 2.205696209554209
# CQR: Runtime:  20.704322474000946
# CQR: Pct in range (expecting 91.20879120879121%): 91.58
# QRF: Pct in range (expecting 91.20879120879121%): 89.18
# CQR: Average length: 2.0855936177163437
# QRF: Average length: 2.2507382760976316
# CQR: Runtime:  21.971813657000894
# CQR: Pct in range (expecting 91.20879120879121%): 89.78
# QRF: Pct in range (expecting 91.20879120879121%): 90.03999999999999
# CQR: Average length: 2.0193735094445815
# QRF: Average length: 2.2549193393062117
# CQR: Runtime:  20.62083610600166
# CQR: Pct in range (expecting 91.20879120879121%): 92.2
# QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR: Average length: 2.060970372999159
# QRF: Average length: 2.2327078345465843
# CQR: Runtime:  20.690555902998312
# CQR: Pct in range (expecting 91.20879120879121%): 90.56
# ...
# CQR: Pct in range (expecting 91.20879120879121%): 91.38
# QRF: Pct in range (expecting 91.20879120879121%): 89.56
# CQR: Average length: 2.0507500089906534
# QRF: Average length: 2.2772393166490534
# CQR: Runtime:  21.910686579998583
# CQR: Pct in range (expecting 91.20879120879121%): 91.42
# QRF: Pct in range (expecting 91.20879120879121%): 90.44
# CQR: Average length: 2.059957327712601
# QRF: Average length: 2.2784020697992995
# CQR: Runtime:  20.583327273001487
# CQR: Pct in range (expecting 91.20879120879121%): 90.94
# QRF: Pct in range (expecting 91.20879120879121%): 89.62
# CQR: Average length: 2.0446414627933245
# QRF: Average length: 2.2264744143794664
# CQR: Runtime:  20.645485925000685
# CQR: Pct in range (expecting 91.20879120879121%): 90.42
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.032504633080811
# QRF: Average length: 2.1485421433181022
# CQR: Runtime:  20.54848682800366
# CQR: Pct in range (expecting 91.20879120879121%): 92.10000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.4
# CQR: Average length: 2.065327058270917
# QRF: Average length: 2.3750485274410953
# CQR: Runtime:  21.986749374002102
# CQR: Pct in range (expecting 91.20879120879121%): 89.14
# QRF: Pct in range (expecting 91.20879120879121%): 88.84
# CQR: Average length: 2.042712447710718
# QRF: Average length: 2.2463988543201507
# CQR: Runtime:  20.512198128002638
# CQR: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.58
# CQR: Average length: 2.066167988744862
# QRF: Average length: 2.191544240710675
# CQR: Runtime:  20.58816136799578
# CQR: Pct in range (expecting 91.20879120879121%): 91.25999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.12
# CQR: Average length: 2.064453860774866
# QRF: Average length: 2.29105635165387
# CQR: Runtime:  20.549090540996986
# CQR: Pct in range (expecting 91.20879120879121%): 90.98
# QRF: Pct in range (expecting 91.20879120879121%): 89.22
# CQR: Average length: 2.040901839550826
# QRF: Average length: 2.757052034844933
# CQR: Runtime:  21.902772509994975
# CQR: Pct in range (expecting 91.20879120879121%): 90.52
# QRF: Pct in range (expecting 91.20879120879121%): 89.38000000000001
# CQR: Average length: 2.0750115945273135
# QRF: Average length: 2.2541340546510003
# CQR: Runtime:  20.580776625
# CQR: Pct in range (expecting 91.20879120879121%): 90.98
# QRF: Pct in range (expecting 91.20879120879121%): 90.24
# CQR: Average length: 2.058847850974315
# QRF: Average length: 2.316982574990617
# CQR: Runtime:  20.599549671002023
# CQR: Pct in range (expecting 91.20879120879121%): 92.12
# QRF: Pct in range (expecting 91.20879120879121%): 90.02
# CQR: Average length: 2.089772235362588
# QRF: Average length: 2.3616166429586705
# CQR: Runtime:  21.068319630001497
# CQR: Pct in range (expecting 91.20879120879121%): 92.14
# QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR: Average length: 2.093508232314662
# QRF: Average length: 2.292894781716343
# CQR: Runtime:  21.329728022996278
# CQR: Pct in range (expecting 91.20879120879121%): 91.92
# QRF: Pct in range (expecting 91.20879120879121%): 90.68
# CQR: Average length: 2.088727667454174
# QRF: Average length: 2.2940300367773174
# CQR: Runtime:  20.52870331700251
# CQR: Pct in range (expecting 91.20879120879121%): 90.14
# QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR: Average length: 2.0176908810358407
# QRF: Average length: 2.269480067871556
# CQR: Runtime:  20.66150834900327
# CQR: Pct in range (expecting 91.20879120879121%): 91.16
# QRF: Pct in range (expecting 91.20879120879121%): 89.96
# CQR: Average length: 2.0656208873815807
# QRF: Average length: 2.2827894158948636
# CQR: Runtime:  21.88789980099682
# CQR: Pct in range (expecting 91.20879120879121%): 91.72
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.0798718578911597
# QRF: Average length: 2.307593023824045
# CQR: Runtime:  20.635494697999093
# CQR: Pct in range (expecting 91.20879120879121%): 90.8
# QRF: Pct in range (expecting 91.20879120879121%): 89.34
# CQR: Average length: 2.0341013332604794
# QRF: Average length: 2.191925012909993
# CQR: Runtime:  20.51840994599479
# CQR: Pct in range (expecting 91.20879120879121%): 92.2
# QRF: Pct in range (expecting 91.20879120879121%): 91.44
# CQR: Average length: 2.076961783367426
# QRF: Average length: 2.308391154118704
# CQR: Runtime:  20.616832384999725
# CQR: Pct in range (expecting 91.20879120879121%): 93.08
# QRF: Pct in range (expecting 91.20879120879121%): 90.98
# CQR: Average length: 2.1019913840190805
# QRF: Average length: 2.3274024403360354
# CQR: Runtime:  21.798130041002878
# CQR: Pct in range (expecting 91.20879120879121%): 91.08000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.24
# CQR: Average length: 2.058796774272376
# QRF: Average length: 2.2436672291212205
# CQR: Runtime:  20.608427090999612
# CQR: Pct in range (expecting 91.20879120879121%): 90.9
# QRF: Pct in range (expecting 91.20879120879121%): 90.12
# CQR: Average length: 2.049903011461476
# QRF: Average length: 2.300440612588432
# CQR: Runtime:  20.60168142900511
# CQR: Pct in range (expecting 91.20879120879121%): 91.2
# QRF: Pct in range (expecting 91.20879120879121%): 89.58
# CQR: Average length: 2.0520095414147566
# QRF: Average length: 2.2651095309616265
# CQR: Runtime:  20.59349329199904
# CQR: Pct in range (expecting 91.20879120879121%): 91.66
# QRF: Pct in range (expecting 91.20879120879121%): 90.62
# CQR: Average length: 2.049658666444273
# QRF: Average length: 2.315081479673763
# CQR: Runtime:  21.807568333002564
# CQR: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.7
# CQR: Average length: 2.03415729094264
# QRF: Average length: 2.2719052652561507
# CQR: Runtime:  20.67609017700306
# CQR: Pct in range (expecting 91.20879120879121%): 89.62
# QRF: Pct in range (expecting 91.20879120879121%): 89.25999999999999
# CQR: Average length: 2.0086929166906757
# QRF: Average length: 2.2473166861474905
# CQR: Runtime:  20.60079044800659
# CQR: Pct in range (expecting 91.20879120879121%): 91.78
# QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR: Average length: 2.0534099708121705
# QRF: Average length: 2.303331041268252
# CQR: Runtime:  20.633169638000254
# CQR: Pct in range (expecting 91.20879120879121%): 90.94
# QRF: Pct in range (expecting 91.20879120879121%): 90.14
# CQR: Average length: 2.057580989917863
# QRF: Average length: 2.2473871944396633
# CQR: Runtime:  22.203066401001706
# CQR: Pct in range (expecting 91.20879120879121%): 92.12
# QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR: Average length: 2.072847990923884
# QRF: Average length: 2.260731167509096
# CQR: Runtime:  20.628860811004415
# CQR: Pct in range (expecting 91.20879120879121%): 90.4
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.0498339066257576
# QRF: Average length: 2.249704479909323
# CQR: Runtime:  20.572567456001707
# CQR: Pct in range (expecting 91.20879120879121%): 92.12
# QRF: Pct in range (expecting 91.20879120879121%): 90.60000000000001
# CQR: Average length: 2.0487842013117987
# QRF: Average length: 2.227902042563372
# CQR: Runtime:  20.586360359004175
# CQR: Pct in range (expecting 91.20879120879121%): 91.24
# QRF: Pct in range (expecting 91.20879120879121%): 89.53999999999999
# CQR: Average length: 2.0672024257433494
# QRF: Average length: 2.3171618490477996
# CQR: Runtime:  21.88801495899679
# CQR: Pct in range (expecting 91.20879120879121%): 91.52
# QRF: Pct in range (expecting 91.20879120879121%): 90.53999999999999
# CQR: Average length: 2.0518678788774345
# QRF: Average length: 2.3228315293666237
# CQR: Runtime:  20.6861496240017
# CQR: Pct in range (expecting 91.20879120879121%): 92.24
# QRF: Pct in range (expecting 91.20879120879121%): 89.82
# CQR: Average length: 2.063273588478427
# QRF: Average length: 2.238911296512499
# CQR: Runtime:  20.662871685002756
# CQR: Pct in range (expecting 91.20879120879121%): 90.5
# QRF: Pct in range (expecting 91.20879120879121%): 89.74
# CQR: Average length: 2.0325304700322397
# QRF: Average length: 2.2430977585816683
# CQR: Runtime:  20.592159993000678
# CQR: Pct in range (expecting 91.20879120879121%): 92.12
# QRF: Pct in range (expecting 91.20879120879121%): 90.24
# CQR: Average length: 2.1005434037329396
# QRF: Average length: 2.260830734392386
# CQR: Runtime:  21.817593214997032
# CQR: Pct in range (expecting 91.20879120879121%): 92.04
# QRF: Pct in range (expecting 91.20879120879121%): 90.56
# CQR: Average length: 2.0907961753751887
# QRF: Average length: 2.3154790690509297
# CQR: Runtime:  20.48300972799916
# CQR: Pct in range (expecting 91.20879120879121%): 91.96
# QRF: Pct in range (expecting 91.20879120879121%): 90.32
# CQR: Average length: 2.0476331976234383
# QRF: Average length: 2.2773221006750894
# CQR: Runtime:  20.596476430997427
# CQR: Pct in range (expecting 91.20879120879121%): 91.56
# QRF: Pct in range (expecting 91.20879120879121%): 90.46
# CQR: Average length: 2.034554749754431
# QRF: Average length: 2.2235303937981494
# CQR: Runtime:  20.580516600995907
# CQR: Pct in range (expecting 91.20879120879121%): 92.02
# QRF: Pct in range (expecting 91.20879120879121%): 90.36
# CQR: Average length: 2.0600984791952994
# QRF: Average length: 2.246576193983896
# CQR: Runtime:  21.91297959100484
# CQR: Pct in range (expecting 91.20879120879121%): 89.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 89.18
# CQR: Average length: 2.041475041882121
# QRF: Average length: 2.152277437647446
# CQR: Runtime:  20.86078543700569
# CQR: Pct in range (expecting 91.20879120879121%): 90.16
# QRF: Pct in range (expecting 91.20879120879121%): 89.16
# CQR: Average length: 2.0153428004000125
# QRF: Average length: 2.1875821420413746
# CQR: Runtime:  20.48952382200514
# CQR: Pct in range (expecting 91.20879120879121%): 90.48
# QRF: Pct in range (expecting 91.20879120879121%): 89.96
# CQR: Average length: 2.0284014560463532
# QRF: Average length: 2.176260831241516
# CQR: Runtime:  20.5484356320012
# CQR: Pct in range (expecting 91.20879120879121%): 91.72
# QRF: Pct in range (expecting 91.20879120879121%): 90.84
# CQR: Average length: 2.0683798233323776
# QRF: Average length: 2.3565815811621253
# CQR: Runtime:  21.866269402999023
# CQR: Pct in range (expecting 91.20879120879121%): 91.9
# QRF: Pct in range (expecting 91.20879120879121%): 89.48
# CQR: Average length: 2.065809201896256
# QRF: Average length: 2.2453216871149655
# CQR: Runtime:  20.565119378006784
# CQR: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.32
# CQR: Average length: 2.0592532610106615
# QRF: Average length: 2.261575830237901
# CQR: Runtime:  20.537583987999824
# CQR: Pct in range (expecting 91.20879120879121%): 91.92
# QRF: Pct in range (expecting 91.20879120879121%): 89.3
# CQR: Average length: 2.061942342182231
# QRF: Average length: 2.2869839668662877
# CQR: Runtime:  20.63973697199981
# CQR: Pct in range (expecting 91.20879120879121%): 91.7
# QRF: Pct in range (expecting 91.20879120879121%): 89.8
# CQR: Average length: 2.0702225828832024
# QRF: Average length: 2.270208436786687
# CQR: Runtime:  21.923604456002067
# CQR: Pct in range (expecting 91.20879120879121%): 91.58
# QRF: Pct in range (expecting 91.20879120879121%): 89.72
# CQR: Average length: 2.062597921608524
# QRF: Average length: 2.180169091372444
# CQR: Runtime:  20.686143154998717
# CQR: Pct in range (expecting 91.20879120879121%): 90.52
# QRF: Pct in range (expecting 91.20879120879121%): 89.74
# CQR: Average length: 2.054602955375174
# QRF: Average length: 2.2577008768845417
# CQR: Runtime:  20.60843945099623
# CQR: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.2
# CQR: Average length: 2.0640049098111644
# QRF: Average length: 2.2218778455214916
# CQR: Runtime:  20.63690640299319
# CQR: Pct in range (expecting 91.20879120879121%): 90.36
# QRF: Pct in range (expecting 91.20879120879121%): 89.75999999999999
# CQR: Average length: 2.0471126403014606
# QRF: Average length: 2.2391861562057334
# CQR: Runtime:  21.853498948999913
# CQR: Pct in range (expecting 91.20879120879121%): 91.62
# QRF: Pct in range (expecting 91.20879120879121%): 90.72
# CQR: Average length: 2.049800244145059
# QRF: Average length: 2.289345816951741
# CQR: Runtime:  20.774096690001898
# CQR: Pct in range (expecting 91.20879120879121%): 89.0
# QRF: Pct in range (expecting 91.20879120879121%): 88.98
# CQR: Average length: 1.9680537980749748
# QRF: Average length: 2.118690207991413
# CQR: Runtime:  21.604946320003364
# CQR: Pct in range (expecting 91.20879120879121%): 92.67999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 91.32000000000001
# CQR: Average length: 2.1033547176238345
# QRF: Average length: 2.357911742171401
# CQR: Runtime:  21.55882971900428
# CQR: Pct in range (expecting 91.20879120879121%): 89.05999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 89.56
# CQR: Average length: 2.010981232996723
# QRF: Average length: 2.192547577421598
# CQR: Runtime:  22.81657097000425
# CQR: Pct in range (expecting 91.20879120879121%): 91.36
# QRF: Pct in range (expecting 91.20879120879121%): 89.98
# CQR: Average length: 2.0476536159581724
# QRF: Average length: 2.2727735127844935
# CQR: Runtime:  21.513927304004028
# CQR: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QRF: Pct in range (expecting 91.20879120879121%): 90.60000000000001
# CQR: Average length: 2.027353396514592
# QRF: Average length: 2.2934921481084447
# CQR: Runtime:  21.497012471001653
# CQR: Pct in range (expecting 91.20879120879121%): 89.56
# QRF: Pct in range (expecting 91.20879120879121%): 88.2
# CQR: Average length: 2.020392283743407
# QRF: Average length: 2.2480770504263186
# CQR: Runtime:  21.50441919599689
# CQR: Pct in range (expecting 91.20879120879121%): 91.42
# QRF: Pct in range (expecting 91.20879120879121%): 90.38000000000001
# CQR: Average length: 2.0756006907814286
# QRF: Average length: 2.3206365696971836
# CQR: Runtime:  22.160229196000728
# CQR: Pct in range (expecting 91.20879120879121%): 92.0
# QRF: Pct in range (expecting 91.20879120879121%): 89.75999999999999
# CQR: Average length: 2.05671238407587
# QRF: Average length: 2.216086086525435
# CQR: Runtime:  20.63635127100133
# CQR: Pct in range (expecting 91.20879120879121%): 91.34
# QRF: Pct in range (expecting 91.20879120879121%): 90.28
# CQR: Average length: 2.051282730131821
# QRF: Average length: 2.19949476868444
# CQR: Runtime:  20.682547793003323
# CQR: Pct in range (expecting 91.20879120879121%): 89.98
# QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR: Average length: 2.0020970344961935
# QRF: Average length: 2.145910826251176
# CQR: Runtime:  20.625460369999928
# CQR: Pct in range (expecting 91.20879120879121%): 91.34
# QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR: Average length: 2.0687484652395893
# QRF: Average length: 2.433135270688126
# CQR: Runtime:  21.93654627000069
# CQR: Pct in range (expecting 91.20879120879121%): 91.14
# QRF: Pct in range (expecting 91.20879120879121%): 89.82
# CQR: Average length: 2.043320334093186
# QRF: Average length: 2.294216620207294
# CQR: Runtime:  20.54833159599366
# CQR: Pct in range (expecting 91.20879120879121%): 93.12
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.108157723085122
# QRF: Average length: 2.3205018068777563
# CQR: Runtime:  20.52523013699829
# CQR: Pct in range (expecting 91.20879120879121%): 92.75999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.68
# CQR: Average length: 2.0960755651452256
# QRF: Average length: 2.281444807851907
# CQR: Runtime:  20.64215953800158
# CQR: Pct in range (expecting 91.20879120879121%): 90.74
# QRF: Pct in range (expecting 91.20879120879121%): 89.48
# CQR: Average length: 2.0394059186519145
# QRF: Average length: 2.2452848837373445
# CQR: Runtime:  21.96341823200055
# CQR: Pct in range (expecting 91.20879120879121%): 91.02
# QRF: Pct in range (expecting 91.20879120879121%): 89.84
# CQR: Average length: 2.056844728871792
# QRF: Average length: 2.239640209988555
# CQR: Runtime:  20.672415954002645
# CQR: Pct in range (expecting 91.20879120879121%): 91.53999999999999
# QRF: Pct in range (expecting 91.20879120879121%): 90.03999999999999
# CQR: Average length: 2.0682842736963196
# QRF: Average length: 2.2490546074799918
# CQR: Runtime:  20.893625636999786

# %% [markdown]
# ## **Quantile Random Forest (QRF)**
# Fit $R=1000$ QRF on combined proper training and calibration set. This predictor does not have a finite sample guarantee. The results are used to compare QRF to CQR.

# %%
# define quantile random forests (QRF) parameters
params_qforest = dict()
params_qforest["n_estimators"] = 100
params_qforest["min_samples_leaf"] = 40
params_qforest["max_features"] = 1
params_qforest["CV"] = False
params_qforest["random_state"] = seed

# %%
def qrf_loop(
      R = 100,
      n_train = 100,
      n_test = 100,
      alpha = 0.05,
      save_run = False,
      filename = None):

    results = np.array([[0]*3]*R, dtype=float)

    for i in range(R):

        start = timeit.default_timer()

        # training calibration and test features
        x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
        x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

        # generate labels
        y_train = f(x_train)
        y_test = f(x_test)

        # reshape the features
        x_train = np.reshape(x_train,(n_train, 1))
        x_test = np.reshape(x_test,(n_test, 1))

        # define the QRF model
        quantile_estimator = helper.QuantileForestRegressorAdapter(model=None,
                                                           fit_params=None,
                                                           quantiles=quantiles,
                                                           params=params_qforest)

        # fit the conditional quantile regression to the proper training data
        quantile_estimator.fit(x_train, y_train)

        # compute the low and high conditional quantile estimation
        pred_qr = quantile_estimator.predict(x_test)
        y_lower_qr = pred_qr[:,0]
        y_upper_qr = pred_qr[:,1]

        # compute and display the average coverage
        in_the_range_qr = np.sum((y_test >= y_lower_qr) & (y_test <= y_upper_qr))
        print("QR QRF : Pct in range (expecting " + str(100*(1-alpha)*params_qforest["coverage_factor"]) + "%):",
              in_the_range_qr / len(y_test) * 100)
        results[i][0] = in_the_range_qr / len(y_test) * 100

        # compute length of the conformal interval per each test point
        length_qr_rf = y_upper_qr - y_lower_qr
        print("QR QRF : Average length:", np.mean(length_qr_rf))
        results[i][1] = np.mean(length_qr_rf)

        stop = timeit.default_timer()
        print('QR QRF : Runtime: ', stop - start)
        results[i][2] = stop - start
    
    results = pd.DataFrame(results,
                           columns = ['QR Pct in range', 'QR Avg length', 'Runtime'])
    
    if save_run and (filename is not None):
      results.to_csv(filename, index=False)

    return(results)

# %%
np.random.seed(seed)

run = qrf_loop(
      R = R,
      n_train = n_train+n_cal,
      n_test = n_test,
      alpha = alpha,
      save_run = save_run,
      filename = "Experiments Output/toy_qrf_s23_R1000.csv")
# Out:
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.24
# QR QRF : Average length: 2.285731692099384
# QR QRF : Runtime:  11.94869684599999
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.58
# QR QRF : Average length: 2.418481721268504
# QR QRF : Runtime:  11.941096606000002
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.82
# QR QRF : Average length: 2.3581724423659356
# QR QRF : Runtime:  12.016989051999985
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.98
# QR QRF : Average length: 2.3924983472183774
# QR QRF : Runtime:  12.018348469000017
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.84
# QR QRF : Average length: 2.367103494395127
# QR QRF : Runtime:  12.173513461999988
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.36
# QR QRF : Average length: 2.4783411547990735
# QR QRF : Runtime:  13.51237711600001
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.60000000000001
# QR QRF : Average length: 2.440089951147037
# QR QRF : Runtime:  12.141693674999999
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.8
# QR QRF : Average length: 2.3758471104149854
# QR QRF : Runtime:  12.448261349000006
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.14
# QR QRF : Average length: 2.4056606038488924
# QR QRF : Runtime:  11.982714079999994
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.68
# QR QRF : Average length: 2.2851254119870994
# QR QRF : Runtime:  12.181567747000031
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.36
# QR QRF : Average length: 2.220581703249798
# QR QRF : Runtime:  12.140668141999981
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.24
# QR QRF : Average length: 2.341839170170005
# QR QRF : Runtime:  12.00402773999997
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.03999999999999
# QR QRF : Average length: 2.3529628225253427
# QR QRF : Runtime:  12.173474349999992
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.86
# QR QRF : Average length: 2.4802342178023795
# QR QRF : Runtime:  11.960396836999962
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.48
# QR QRF : Average length: 2.2525917271624696
# QR QRF : Runtime:  12.094306483000025
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.78
# QR QRF : Average length: 2.386987938306985
# QR QRF : Runtime:  11.956688664000012
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.38000000000001
# QR QRF : Average length: 2.2735092449523844
# QR QRF : Runtime:  11.831900160000032
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.03999999999999
# QR QRF : Average length: 2.3430944031118037
# QR QRF : Runtime:  12.186233806000018
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.03999999999999
# QR QRF : Average length: 2.1978082224274016
# QR QRF : Runtime:  12.02880074799998
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.02
# QR QRF : Average length: 2.398182470799639
# QR QRF : Runtime:  12.082496702999947
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.12
# QR QRF : Average length: 2.3920996318632533
# QR QRF : Runtime:  12.337474144999987
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.4
# QR QRF : Average length: 2.3944190553768987
# QR QRF : Runtime:  11.849075362000008
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.14
# QR QRF : Average length: 2.2475044816564598
# QR QRF : Runtime:  12.024864609999952
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.12
# QR QRF : Average length: 2.203612438357348
# QR QRF : Runtime:  12.076372004000007
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.0
# QR QRF : Average length: 2.393297258974153
# QR QRF : Runtime:  11.962588641999957
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.42
# QR QRF : Average length: 2.326427211349561
# QR QRF : Runtime:  12.341678918000014
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.1
# QR QRF : Average length: 2.5539042383286112
# QR QRF : Runtime:  11.92595117999997
# QR QRF : Pct in range (expecting 91.20879120879121%): 90
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.72
# QR QRF : Average length: 2.459805209410012
# QR QRF : Runtime:  11.83203080300018
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.06
# QR QRF : Average length: 2.4650071072312842
# QR QRF : Runtime:  11.855963932000122
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.46
# QR QRF : Average length: 2.2644359388312574
# QR QRF : Runtime:  11.748102879000271
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.28
# QR QRF : Average length: 2.295110550485008
# QR QRF : Runtime:  11.900252081999952
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.44
# QR QRF : Average length: 2.311473429449673
# QR QRF : Runtime:  11.98234244599962
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.44
# QR QRF : Average length: 2.3030685694438553
# QR QRF : Runtime:  11.957584056000087
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.14
# QR QRF : Average length: 2.430068304682009
# QR QRF : Runtime:  11.952872548999949
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.56
# QR QRF : Average length: 2.4864007076624945
# QR QRF : Runtime:  11.731625766999969
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.38000000000001
# QR QRF : Average length: 2.2168521570795208
# QR QRF : Runtime:  11.855999591
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.28
# QR QRF : Average length: 2.298296384797914
# QR QRF : Runtime:  11.874976123000124
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.3
# QR QRF : Average length: 2.2781394141632334
# QR QRF : Runtime:  11.752031259999967
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.66
# QR QRF : Average length: 2.436807648400351
# QR QRF : Runtime:  11.934179165999922
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.7
# QR QRF : Average length: 2.493845138175722
# QR QRF : Runtime:  11.761939526000333
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.05999999999999
# QR QRF : Average length: 2.333937143709414
# QR QRF : Runtime:  11.853042954000102
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.14
# QR QRF : Average length: 2.2535157754969974
# QR QRF : Runtime:  11.839775031000045
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.56
# QR QRF : Average length: 2.3163441960725706
# QR QRF : Runtime:  11.796689651999714
# QR QRF : Pct in range (expecting 91.20879120879121%): 88.1
# QR QRF : Average length: 2.258926868147377
# QR QRF : Runtime:  12.087365352000234
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.12
# QR QRF : Average length: 2.2412730344311464
# QR QRF : Runtime:  12.223060723000344
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.03999999999999
# QR QRF : Average length: 2.214342847953976
# QR QRF : Runtime:  12.263219457000105
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.03999999999999
# QR QRF : Average length: 2.293481288344079
# QR QRF : Runtime:  12.578728030000093
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.34
# QR QRF : Average length: 2.596753289723063
# QR QRF : Runtime:  11.798771372000374
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.12
# QR QRF : Average length: 2.3104413131007315
# QR QRF : Runtime:  12.120827966999968
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.92
# QR QRF : Average length: 2.3871662356365575
# QR QRF : Runtime:  11.923219034999875
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.2
# QR QRF : Average length: 2.294993497935091
# QR QRF : Runtime:  12.119477885999913
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.46
# QR QRF : Average length: 2.300564603917189
# QR QRF : Runtime:  12.111474298999838
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.74
# QR QRF : Average length: 2.2283015406488014
# QR QRF : Runtime:  11.876223890000347
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.12
# QR QRF : Average length: 2.339722137426365
# QR QRF : Runtime:  12.11078801900021
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.66
# QR QRF : Average length: 2.274635353994874
# QR QRF : Runtime:  12.15818048400024
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.82
# QR QRF : Average length: 2.22013022969071
# QR QRF : Runtime:  11.985031024999898
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QR QRF : Average length: 2.4274800582249236
# QR QRF : Runtime:  12.183394528000008
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.64
# QR QRF : Average length: 2.3203341556256163
# QR QRF : Runtime:  11.873129917999904
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.82000000000001
# QR QRF : Average length: 2.339433972985918
# QR QRF : Runtime:  12.260188692000156
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.52
# QR QRF : Average length: 2.309849803587829
# QR QRF : Runtime:  12.058811104000142
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QR QRF : Average length: 2.4482210100701667
# QR QRF : Runtime:  11.98337852099985
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.46
# QR QRF : Average length: 2.3068888780553416
# QR QRF : Runtime:  11.826576810999995
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.68
# QR QRF : Average length: 2.8893413087602715
# QR QRF : Runtime:  11.674465587000213
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.36
# QR QRF : Average length: 2.3524614811014524
# QR QRF : Runtime:  11.885373718999745
# QR QRF : Pct in range (expecting 91.20879120879121%): 89
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.2
# QR QRF : Average length: 2.2466024021846076
# QR QRF : Runtime:  11.861392351000177
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.06
# QR QRF : Average length: 2.375525047600924
# QR QRF : Runtime:  12.094384144000287
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.72
# QR QRF : Average length: 2.4283064250414426
# QR QRF : Runtime:  11.924729524000213
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.92
# QR QRF : Average length: 2.263434189942137
# QR QRF : Runtime:  11.910626760000014
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.82000000000001
# QR QRF : Average length: 2.3530246276588938
# QR QRF : Runtime:  11.957716089000314
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.4
# QR QRF : Average length: 2.4246917469588087
# QR QRF : Runtime:  11.830619950000255
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.74
# QR QRF : Average length: 2.404378136531316
# QR QRF : Runtime:  12.00950326200109
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.7
# QR QRF : Average length: 2.293358665725294
# QR QRF : Runtime:  11.998818009999013
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.34
# QR QRF : Average length: 2.395587287771281
# QR QRF : Runtime:  11.91338810399975
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.96
# QR QRF : Average length: 2.2468086776652685
# QR QRF : Runtime:  12.111272973999803
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.58
# QR QRF : Average length: 2.310789512171127
# QR QRF : Runtime:  11.910856586999216
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.60000000000001
# QR QRF : Average length: 2.5617213051172607
# QR QRF : Runtime:  11.988464269999895
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.42
# QR QRF : Average length: 2.327612903364072
# QR QRF : Runtime:  11.863834715999474
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.52
# QR QRF : Average length: 2.505361681149267
# QR QRF : Runtime:  11.76844079500006
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.16
# QR QRF : Average length: 2.274893170664138
# QR QRF : Runtime:  11.927429917999689
# QR QRF : Pct in range (expecting 91.20879120879121%): 88.22
# QR QRF : Average length: 2.2983660033977804
# QR QRF : Runtime:  11.773347057000137
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.52
# QR QRF : Average length: 2.7526208195282225
# QR QRF : Runtime:  12.111509600999852
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.52
# QR QRF : Average length: 2.389197941496814
# QR QRF : Runtime:  11.896847281999726
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.36
# QR QRF : Average length: 2.3447456864034577
# QR QRF : Runtime:  11.906278508000469
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.25999999999999
# QR QRF : Average length: 2.259388336351429
# QR QRF : Runtime:  12.066803088000597
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.0
# QR QRF : Average length: 2.4174318077557517
# QR QRF : Runtime:  11.902388608001274
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.64
# QR QRF : Average length: 2.2909879489695624
# QR QRF : Runtime:  12.323819076998916
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.0
# QR QRF : Average length: 2.3375662744267567
# QR QRF : Runtime:  12.04738225300025
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.28
# QR QRF : Average length: 2.265349255939117
# QR QRF : Runtime:  11.989324141999532
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.24
# QR QRF : Average length: 2.3718699377402883
# QR QRF : Runtime:  12.036272695000662
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.24
# QR QRF : Average length: 2.173271601828106
# QR QRF : Runtime:  12.002386304999163
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QR QRF : Average length: 2.325400667495945
# QR QRF : Runtime:  12.01352061200123
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.4
# QR QRF : Average length: 2.2790464770447656
# QR QRF : Runtime:  11.88631371000156
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.14
# QR QRF : Average length: 2.248304230254853
# QR QRF : Runtime:  11.975025952000578
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.42
# QR QRF : Average length: 2.33407859238865
# QR QRF : Runtime:  11.902340786000423
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.68
# QR QRF : Average length: 3.202062232212801
# QR QRF : Runtime:  12.029210417000286
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.84
# QR QRF : Average length: 2.307391989214175
# QR QRF : Runtime:  12.021805734999361
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.74
# QR QRF : Average length: 2.284221937757867
# QR QRF : Runtime:  12.050451823000913
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.47999999999999
# QR QRF : Average length: 2.331594436897148
# QR QRF : Runtime:  12.105888514999606
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.75999999999999
# QR QRF : Average length: 2.3346341544380955
# QR QRF : Runtime:  11.950562988999081
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.88000000000001
# QR QRF : Average length: 2.3878472260575627
# QR QRF : Runtime:  11.978439920998426
# QR QRF : Pct in range (expecting 91.20879120879121%): 90
# QR QRF : Pct in range (expecting 91.20879120879121%): 88.58
# QR QRF : Average length: 2.5025258437776587
# QR QRF : Runtime:  12.022793616000854
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.34
# QR QRF : Average length: 2.411357678519655
# QR QRF : Runtime:  12.236937685000157
# QR QRF : Pct in range (expecting 91.20879120879121%): 88.96
# QR QRF : Average length: 2.1298623723798693
# QR QRF : Runtime:  12.732063047998963
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.14
# QR QRF : Average length: 2.2604080018179635
# QR QRF : Runtime:  12.222172740999667
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.22
# QR QRF : Average length: 2.3394196439889403
# QR QRF : Runtime:  12.398312365001402
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.02
# QR QRF : Average length: 2.371110428729374
# QR QRF : Runtime:  12.108231730000625
# QR QRF : Pct in range (expecting 91.20879120879121%): 88.94
# QR QRF : Average length: 2.2198283212383454
# QR QRF : Runtime:  12.070701898999687
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.44
# QR QRF : Average length: 2.3855015733847913
# QR QRF : Runtime:  12.250607531999776
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.36
# QR QRF : Average length: 2.3655792649280776
# QR QRF : Runtime:  11.834840147999785
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.10000000000001
# QR QRF : Average length: 2.392733084857126
# QR QRF : Runtime:  12.19406882200019
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.86
# QR QRF : Average length: 2.3079610832012345
# QR QRF : Runtime:  12.221411753998837
# QR QRF : Pct in range (expecting 91.20879120879121%): 91.56
# QR QRF : Average length: 2.3456704178100916
# QR QRF : Runtime:  12.0003138510001
# QR QRF : Pct in range (expecting 91.20879120879121%): 90.53999999999999
# QR QRF : Average length: 2.193789882910777
# QR QRF : Runtime:  12.448223067000072
# QR QRF : Pct in range (expecting 91.20879120879121%): 89.58
# QR QRF : Average length: 2.2559508331940474
# QR QRF : Runtime:  12.236857456999132

# %% [markdown]
# ## **CQR Tolerance Regions (1 predictor) (NOT USED IN FINAL DRAFT)**
#
# Fit 1 predictor, repeat calibration and test procedure R times

# %%
# define quantile random forests (QRF) parameters
params_qforest = dict()
params_qforest["n_estimators"] = 100
params_qforest["min_samples_leaf"] = 40
params_qforest["max_features"] = 1
params_qforest["CV"] = True
params_qforest["coverage_factor"] = 0.9
params_qforest["test_ratio"] = 0.1
params_qforest["random_state"] = seed
params_qforest["range_vals"] = 30
params_qforest["num_vals"] = 10

# %%
np.random.seed(seed)

start = timeit.default_timer()

# training features
x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

# generate labels
y_train = f(x_train)
y_test = f(x_test)

# reshape the features
x_train = np.reshape(x_train,(n_train, 1))
x_test = np.reshape(x_test,(n_test,1))

# define the QRF model
quantile_estimator = helper.QuantileForestRegressorAdapter(model=None,
                                                           fit_params=None,
                                                           quantiles=quantiles,
                                                           params=params_qforest)

# define the CQR object, computing the absolute residual error of points 
# located outside the estimated QRF band 
nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

# build the split CQR object
icp = IcpRegressor(nc)

# fit the conditional quantile regression to the proper training data
icp.fit(x_train, y_train)

# compute the low and high conditional quantile estimation
pred_qr_qrf = quantile_estimator.predict(x_test)
y_lower_qr_qrf = pred_qr_qrf[:,0]
y_upper_qr_qrf = pred_qr_qrf[:,1]

# compute and display the average coverage
in_the_range_qr_qrf = np.sum((y_test >= y_lower_qr_qrf) & (y_test <= y_upper_qr_qrf))
print("QR QRF : Pct in range (expecting " + str(100*(1-alpha)*params_qforest["coverage_factor"]) + "%):", in_the_range_qr_qrf / len(y_test) * 100)

# compute and display length of the conformal interval per each test point
length_qr_qrf = y_upper_qr_qrf - y_lower_qr_qrf
print("QR QRF : Average length:", np.mean(length_qr_qrf))

stop = timeit.default_timer()
print('QR QRF: Time: ', stop - start)
# Out:
# QR QRF : Pct in range (expecting 82.08791208791209%): 88.22
# QR QRF : Average length: 2.238784660092443
# QR QRF: Time:  10.657129113002156

# %%
def cqr_loop(
      R = 100,
      n_cal = 100,
      n_test = 100,
      alpha = 0.05,
      save_run = False,
      filename = None):

    results = np.array([[0]*3]*R, dtype=float)

    for i in range(R):

        start = timeit.default_timer()

        # calibration and test features
        x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
        x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

        # generate labels
        y_cal = f(x_cal)
        y_test = f(x_test)

        # reshape the features
        x_cal = np.reshape(x_cal,(n_cal, 1))  
        x_test = np.reshape(x_test,(n_test,1))

        # compute the absolute errors on calibration data
        icp.calibrate(x_cal, y_cal)

        # produce predictions for the test set, with confidence equal to significance
        predictions = icp.predict(x_test, significance=alpha)
        y_lower = predictions[:,0]
        y_upper = predictions[:,1]

        # compute and display the average coverage
        in_the_range_cqr_qrf = np.sum((y_test >= y_lower) & (y_test <= y_upper))
        print("CQR QRF: Pct in range (expecting " + str(100*(1-alpha)) + "%):", in_the_range_cqr_qrf / len(y_test) * 100)
        results[i][0] = in_the_range_cqr_qrf / len(y_test) * 100

        # compute length of the conformal interval per each test point
        length_cqr_qrf = y_upper - y_lower

        # compute and display the average length
        print("CQR QRF: Average length:", np.mean(length_cqr_qrf))
        results[i][1] = np.mean(length_cqr_qrf)

        stop = timeit.default_timer()
        print('CQR QRF: Runtime: ', stop - start)
        results[i][2] = stop - start
    
    results = pd.DataFrame(results,
                           columns = ['CQR Pct in range', 'CQR Avg length', 'Runtime'])
    
    if save_run and (filename is not None):
      results.to_csv(filename, index=False)

    return(results)

# %%
np.random.seed(seed)

run = cqr_loop(
      R = R,
      n_cal = n_cal,
      n_test = n_test,
      alpha = alpha,
      save_run = save_run,
      filename = "Experiments Output/toy1_s5_R1000.csv")
# Out:
# CQR QRF: Pct in range (expecting 91.20879120879121%): 88.0
# CQR QRF: Average length: 2.236597350788453
# CQR QRF: Runtime:  9.450172028999077
# CQR QRF: Pct in range (expecting 91.20879120879121%): 89.03999999999999
# CQR QRF: Average length: 2.2469773920983194
# CQR QRF: Runtime:  9.507011749999947
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.36
# CQR QRF: Average length: 2.2893707233468437
# CQR QRF: Runtime:  9.361978433997137
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# CQR QRF: Average length: 2.2722311672361006
# CQR QRF: Runtime:  9.527349117000995
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.36
# CQR QRF: Average length: 2.2675992870524273
# CQR QRF: Runtime:  9.404290390000824
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.4
# CQR QRF: Average length: 2.268595278319664
# CQR QRF: Runtime:  9.443141533000016
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.86
# CQR QRF: Average length: 2.2715564231435885
# CQR QRF: Runtime:  10.731363965998753
# CQR QRF: Pct in range (expecting 91.20879120879121%): 89.68
# CQR QRF: Average length: 2.2236605906667517
# CQR QRF: Runtime:  9.481689111999003
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.88
# CQR QRF: Average length: 2.2631552498217165
# CQR QRF: Runtime:  9.403565215001436
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.78
# CQR QRF: Average length: 2.2672049398787903
# CQR QRF: Runtime:  9.399414224000793
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.08
# CQR QRF: Average length: 2.275960083000002
# CQR QRF: Runtime:  9.42011978699884
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.25999999999999
# CQR QRF: Average length: 2.232041912345137
# CQR QRF: Runtime:  9.36724264499935
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.52
# CQR QRF: Average length: 2.2579657427531643
# CQR QRF: Runtime:  9.452243546002137
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.36
# CQR QRF: Average length: 2.275569917224238
# CQR QRF: Runtime:  9.419366772999638
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90
# CQR QRF: Pct in range (expecting 91.20879120879121%): 93.10000000000001
# CQR QRF: Average length: 2.284974116362295
# CQR QRF: Runtime:  10.81252640800085
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.86
# CQR QRF: Average length: 2.26509221631099
# CQR QRF: Runtime:  9.562121650000336
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.36
# CQR QRF: Average length: 2.2742937307451334
# CQR QRF: Runtime:  9.436643201996048
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.82000000000001
# CQR QRF: Average length: 2.27402739681153
# CQR QRF: Runtime:  9.530702488002134
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.96
# CQR QRF: Average length: 2.2569773940991227
# CQR QRF: Runtime:  9.376791379996575
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.96
# CQR QRF: Average length: 2.3343873059991034
# CQR QRF: Runtime:  9.562698018002266
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR QRF: Average length: 2.2389340690238386
# CQR QRF: Runtime:  9.440606086995103
# CQR QRF: Pct in range (expecting 91.20879120879121%): 89.75999999999999
# CQR QRF: Average length: 2.247268735746006
# CQR QRF: Runtime:  9.717613079003058
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.38
# CQR QRF: Average length: 2.2856439769681334
# CQR QRF: Runtime:  9.479380995995598
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.10000000000001
# CQR QRF: Average length: 2.2613172858231736
# CQR QRF: Runtime:  9.629859502005274
# CQR QRF: Pct in range (expecting 91.20879120879121%): 88.62
# CQR QRF: Average length: 2.2370871860864163
# CQR QRF: Runtime:  9.449400974997843
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.32
# CQR QRF: Average length: 2.259112701818344
# CQR QRF: Runtime:  9.705737147000036
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.82000000000001
# CQR QRF: Average length: 2.2830810870651272
# CQR QRF: Runtime:  9.398182049000752
# CQR QRF: Pct in range (expecting 91.20879120879121%): 89.64
# CQR QRF: Average length: 2.254221228167956
# CQR QRF: Runtime:  9.582896691004862
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# CQR QRF: Average length: 2.2675190109325056
# CQR QRF: Runtime:  10.753505095002765
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.9
# CQR QRF: Average length: 2.297822705074629
# CQR QRF: Runtime:  9.702359534996503
# CQR QRF: Pct in range (expecting 91.20879120879121%): 89.32
# CQR QRF: Average length: 2.241473259204361
# CQR QRF: Runtime:  9.5544196310002
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.58
# CQR QRF: Average length: 2.2785924853167927
# CQR QRF: Runtime:  9.678906283996184
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.56
# CQR QRF: Average length: 2.2797604792445862
# CQR QRF: Runtime:  9.424449981997896
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.88
# CQR QRF: Average length: 2.272290127116062
# CQR QRF: Runtime:  9.566558586004248
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.08000000000001
# CQR QRF: Average length: 2.245551582820016
# CQR QRF: Runtime:  9.377684459002921
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.82000000000001
# CQR QRF: Average length: 2.2860896244300073
# CQR QRF: Runtime:  9.595998377000797
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.97999999999999
# CQR QRF: Average length: 2.298358661771653
# CQR QRF: Runtime:  9.434923296998022
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.60000000000001
# CQR QRF: Average length: 2.28163241351763
# CQR QRF: Runtime:  9.74788949899812
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.34
# CQR QRF: Average length: 2.2693539475756674
# CQR QRF: Runtime:  9.472118250996573
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.06
# CQR QRF: Average length: 2.2532090556969218
# CQR QRF: Runtime:  9.595650306997413
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.0
# CQR QRF: Average length: 2.253785969534139
# CQR QRF: Runtime:  9.395181077998132

# %% [markdown]
# ## **CQR Tolerance Region (R predictors)**
# Repeat CQR procedure $R=1000$ times, so each time a new base predictor

# %%
def cqr_loop_2(
      R = 100,
      n_train = 100,
      n_cal = 100,
      n_test = 100,
      alpha = 0.05,
      save_run = False,
      filename = None):

    results = np.array([[0]*3]*R, dtype=float)

    for i in range(R):

        start = timeit.default_timer()

        # train, calibration and test features
        x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
        x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
        x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

        # generate labels
        y_train = f(x_train)
        y_cal = f(x_cal)
        y_test = f(x_test)

        # reshape the features
        x_train = np.reshape(x_train,(n_train, 1)) 
        x_cal = np.reshape(x_cal,(n_cal, 1))  
        x_test = np.reshape(x_test,(n_test,1))

        # define the QRF model
        quantile_estimator = helper.QuantileForestRegressorAdapter(model=None,
                                                           fit_params=None,
                                                           quantiles=quantiles,
                                                           params=params_qforest)

        # define the CQR object, computing the absolute residual error of points 
        # located outside the estimated QRF band 
        nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

        # build the split CQR object
        icp = IcpRegressor(nc)

        # fit the conditional quantile regression to the proper training data
        icp.fit(x_train, y_train)

        # compute the absolute errors on calibration data
        icp.calibrate(x_cal, y_cal)

        # produce predictions for the test set, with confidence equal to significance
        predictions = icp.predict(x_test, significance=alpha)
        y_lower = predictions[:,0]
        y_upper = predictions[:,1]

        # compute and display the average coverage
        in_the_range_cqr_qrf = np.sum((y_test >= y_lower) & (y_test <= y_upper))
        print("CQR QRF: Pct in range (expecting " + str(100*(1-alpha)) + "%):", in_the_range_cqr_qrf / len(y_test) * 100)
        results[i][0] = in_the_range_cqr_qrf / len(y_test) * 100

        # compute length of the conformal interval per each test point
        length_cqr_qrf = y_upper - y_lower

        # compute and display the average length
        print("CQR QRF: Average length:", np.mean(length_cqr_qrf))
        results[i][1] = np.mean(length_cqr_qrf)

        stop = timeit.default_timer()
        print('CQR QRF: Runtime: ', stop - start)
        results[i][2] = stop - start
    
    results = pd.DataFrame(results,
                           columns = ['CQR Pct in range', 'CQR Avg length', 'Runtime'])
    
    if save_run and (filename is not None):
      results.to_csv(filename, index=False)

    return(results)

# %%
np.random.seed(seed)

run = cqr_loop_2(
      R = R,
      n_train = n_train,
      n_cal = n_cal,
      n_test = n_test,
      alpha = alpha,
      save_run = save_run,
      filename = "Experiments Output/toy2_cqr_s23_R1000.csv")
# Out:
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.25999999999999
# CQR QRF: Average length: 2.0875833736021674
# CQR QRF: Runtime:  9.14425181599995
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.56
# CQR QRF: Average length: 2.3123323552686426
# CQR QRF: Runtime:  8.876335552
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.56
# CQR QRF: Average length: 2.0840729556738626
# CQR QRF: Runtime:  9.13137401899985
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQR QRF: Average length: 2.1308667642934194
# CQR QRF: Runtime:  9.225671569000042
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.4
# CQR QRF: Average length: 2.433182618875596
# CQR QRF: Runtime:  8.832884093999837
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.30000000000001
# CQR QRF: Average length: 2.0494141012736384
# CQR QRF: Runtime:  9.14235749799991
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.47999999999999
# CQR QRF: Average length: 2.072455727280978
# CQR QRF: Runtime:  9.234579669999903
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.47999999999999
# CQR QRF: Average length: 2.0669991540198143
# CQR QRF: Runtime:  9.046652687000005
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.48
# CQR QRF: Average length: 2.0645022656630254
# CQR QRF: Runtime:  9.017181684999969
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.12
# CQR QRF: Average length: 2.203937996116912
# CQR QRF: Runtime:  8.923467368000047
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.42
# CQR QRF: Average length: 2.1966192100460464
# CQR QRF: Runtime:  8.919214333000127
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.5
# CQR QRF: Average length: 2.120240865267146
# CQR QRF: Runtime:  9.787954892000016
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.0
# CQR QRF: Average length: 2.116407454936432
# CQR QRF: Runtime:  9.760561165000126
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.02
# CQR QRF: Average length: 1.9389758896783735
# CQR QRF: Runtime:  9.925043489000018
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.88000000000001
# CQR QRF: Average length: 1.9333355601549236
# CQR QRF: Runtime:  9.863278164999883
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.96
# CQR QRF: Average length: 2.1065086788527347
# CQR QRF: Runtime:  9.768241864999936
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.56
# CQR QRF: Average length: 2.0164858218148085
# CQR QRF: Runtime:  9.824096200999975
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.74
# CQR QRF: Average length: 2.14787965360452
# CQR QRF: Runtime:  9.756059249999907
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.38
# CQR QRF: Average length: 2.3081528340878905
# CQR QRF: Runtime:  9.59750374400005
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.64
# CQR QRF: Average length: 2.344318616817451
# CQR QRF: Runtime:  9.725412839
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.14
# CQR QRF: Average length: 1.918372744599816
# CQR QRF: Runtime:  9.958559681999986
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.38
# CQR QRF: Average length: 2.0989449094901835
# CQR QRF: Runtime:  9.730959656000095
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.16
# CQ
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.60000000000001
# CQR QRF: Average length: 1.968823123841401
# CQR QRF: Runtime:  9.232866398000624
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.32000000000001
# CQR QRF: Average length: 2.2562833660590904
# CQR QRF: Runtime:  8.950116129999515
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.32000000000001
# CQR QRF: Average length: 1.9933945199384253
# CQR QRF: Runtime:  9.099686448000284
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.72
# CQR QRF: Average length: 1.9799598616138485
# CQR QRF: Runtime:  9.073372073000428
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.0
# CQR QRF: Average length: 2.261609667422367
# CQR QRF: Runtime:  8.953755959999398
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.86
# CQR QRF: Average length: 2.208240804743827
# CQR QRF: Runtime:  9.179768436999439
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.34
# CQR QRF: Average length: 2.225796947114979
# CQR QRF: Runtime:  8.913235300000451
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.2
# CQR QRF: Average length: 2.1942463927491573
# CQR QRF: Runtime:  9.070931562000624
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.86
# CQR QRF: Average length: 2.084363792609815
# CQR QRF: Runtime:  9.034317493000344
# CQR QRF: Pct in range (expecting 91.20879120879121%): 92.2
# CQR QRF: Average length: 2.159569762080949
# CQR QRF: Runtime:  9.03741429799993
# CQR QRF: Pct in range (expecting 91.20879120879121%): 90.66
# CQR QRF: Average length: 1.9886639826916843
# CQR QRF: Runtime:  9.135137147999558
# CQR QRF: Pct in range (expecting 91.20879120879121%): 91.56
# CQR QRF: Average length: 2.071923963238698
# CQR QRF: Runtime:  9.061540411999886

# %% [markdown]
# ## **CQR Neural Net with Rearrangement** (NOT USED IN FINAL DRAFT)
#
# Does not work.

# %%
np.random.seed(seed)

start = timeit.default_timer()

# training calibration and test features
x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

idx_train = list(range(np.int(np.floor(n_train/2))))
idx_cal = list(range(np.int(np.floor(n_train/2)), n_train))

# generate labels
y_train = f(x_train)
y_cal = f(x_cal)
y_test = f(x_test)

# reshape the features
x_train = np.reshape(x_train,(n_train, 1))
x_cal = np.reshape(x_cal,(n_cal, 1))
x_test = np.reshape(x_test,(n_test, 1))

# define quantile neural network model
quantile_estimator = helper.AllQNet_RegressorAdapter(model=None,
                                                     fit_params=None,
                                                     in_shape=1,
                                                     hidden_size=64,
                                                     quantiles=[0.1, 0.9],
                                                     learn_func=torch.optim.Adam,
                                                     epochs=1000,
                                                     batch_size=64,
                                                     dropout=0.1,
                                                     lr=0.0005,
                                                     wd=1e-6,
                                                     test_ratio=0.1,
                                                     random_state=seed,
                                                     use_rearrangement=True)

# define a CQR object, computes the absolute residual error of points 
# located outside the estimated quantile neural network band 
nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

# run CQR procedure
y_lower, y_upper = helper.run_icp(nc, x_train, y_train, x_test, idx_train, idx_cal, alpha)

# compute and print average coverage and average length
coverage_cp_qnet, length_cp_qnet = helper.compute_coverage(y_test,
                                                           y_lower,
                                                           y_upper,
                                                           alpha,
                                                           "CQR Rearrangement Neural Net")

stop = timeit.default_timer()
print('CQR NN: Runtime: ', stop - start)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-2e0381245788> in <module>
#      42
#      43 # run CQR procedure
# ---> 44 y_lower, y_upper = helper.run_icp(nc, x_train, y_train, x_test, idx_train, idx_cal, alpha)
#      45
#      46 # compute and print average coverage and average length
#
# /content/drive/MyDrive/GitHub/dissertation/cqr/helper.py in run_icp(nc, X_train, y_train, X_test, idx_train, idx_cal, significance, condition)
#      66
#      67     # Calibrate the ICP using the calibration set
# ---> 68     icp.calibrate(X_train[idx_cal,:], y_train[idx_cal])
#      69
#      70     # Produce predictions for the test set, with confidence 90%
#
# /content/drive/MyDrive/GitHub/dissertation/nonconformist/icp.py in calibrate(self, x, y, increment)
#     103                 else:
#     104                         self.categories = np.array([0])
# --> 105                         cal_scores = self.nc_function.score(self.cal_x, self.cal_y)
#     106                         self.cal_scores = {0: np.sort(cal_scores,0)[::-1]}
#     107
#
# /content/drive/MyDrive/GitHub/dissertation/nonconformist/nc.py in score(self, x, y)
#     447                         Nonconformity scores of samples.
#     448 		"""
# --> 449                 prediction = self.model.predict(x)
#     450                 n_test = x.shape[0]
#     451                 if self.normalizer is not None:
#
# /content/drive/MyDrive/GitHub/dissertation/cqr/helper.py in predict(self, x)
#     470
#     471         """
# --> 472         return self.learner.predict(x)
#     473
#     474
#
# /content/drive/MyDrive/GitHub/dissertation/cqr/torch_models.py in predict(self, x)
#     497         """
#     498         self.model.eval()
# --> 499         test_preds = self.model(torch.from_numpy(x).to(self.device).requires_grad_(False)).cpu().detach().numpy()
#     500         if self.use_rearrangement:
#     501             test_preds = rearrange(self.all_quantiles, self.quantile_low, self.quantile_high, test_preds)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/MyDrive/GitHub/dissertation/cqr/torch_models.py in forward(self, x)
#     365         """ Run forward pass
#     366         """
# --> 367         return self.base_model(x)
#     368
#     369 class LearnerOptimizedCrossing:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: expected scalar type Float but found Double

# %%
np.random.seed(seed)

start = timeit.default_timer()

# training calibration and test features
x_train = np.random.uniform(0, 5.0, size=n_train).astype(float)
x_cal = np.random.uniform(0, 5.0, size=n_cal).astype(float)
x_test = np.random.uniform(0, 5.0, size=n_test).astype(float)

idx_train = list(range(np.int(np.floor(n_train/2))))
idx_cal = list(range(np.int(np.floor(n_train/2)), n_train))

# generate labels
y_train = f(x_train)
y_cal = f(x_cal)
y_test = f(x_test)

# reshape the features
x_train = np.reshape(x_train,(n_train, 1))
x_cal = np.reshape(x_cal,(n_cal, 1))
x_test = np.reshape(x_test,(n_test, 1))

# define quantile neural network model
quantile_estimator = helper.AllQNet_RegressorAdapter(model=None,
                                                     fit_params=None,
                                                     in_shape=1,
                                                     hidden_size=64,
                                                     quantiles=[0.1, 0.9],
                                                     learn_func=torch.optim.Adam,
                                                     epochs=1000,
                                                     batch_size=64,
                                                     dropout=0.1,
                                                     lr=0.0005,
                                                     wd=1e-6,
                                                     test_ratio=0.1,
                                                     random_state=seed,
                                                     use_rearrangement=False)

# define a CQR object, computes the absolute residual error of points 
# located outside the estimated quantile neural network band 
nc = RegressorNc(quantile_estimator, QuantileRegErrFunc())

# run CQR procedure
y_lower, y_upper = helper.run_icp(nc, x_train, y_train, x_test, idx_train, idx_cal, alpha)

# compute and print average coverage and average length
coverage_cp_qnet, length_cp_qnet = helper.compute_coverage(y_test,
                                                           y_lower,
                                                           y_upper,
                                                           alpha,
                                                           "CQR Rearrangement Neural Net")

stop = timeit.default_timer()
print('CQR NN: Runtime: ', stop - start)
