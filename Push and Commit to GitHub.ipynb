# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GitHub/dissertation

# !git config --global user.email "sann7266@ox.ac.uk"
# !git config --global user.name "Roel Hulsman"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GitHub/dissertation

# %%
# !git status

# %%
# !git add .
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   Push and Commit to GitHub.ipynb

# %%
# !git commit -m "Renamed Files"
# Out:
# [main 716af40] Renamed Files
#  4 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 Clean MEPS Data.ipynb
#  rename Link Google Colab to GitHub.ipynb => Clone Repositories to Drive.ipynb (100%)
#  rename Create Repository.ipynb => Create GitHub Repository.ipynb (100%)
#  create mode 100644 Run Python Scripts.ipynb

# %%
# !git push -u origin "main"
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 971 bytes | 242.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/roelhulsman/dissertation
#    5ed2db8..716af40  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %% [markdown]
# # **Useful commands**

# %%
# !touch .gitignore

# %%
# !git reset HEAD cqr/datasets/blogData_train.csv
# Out:
# Unstaged changes after reset:
# M	.gitignore

# %%
# !git reset --hard HEAD^
# Out:
# HEAD is now at 640a3d2 Added CQR Datasets

# %%
# !git log
# Out:
# commit 469ae3c379a678e354083b0f95094a2ea469cac4 (HEAD -> main, origin/main, origin/HEAD)
# Author: Roel Hulsman <sann7266@ox.ac.uk>
# Date:   Mon Jul 25 16:01:20 2022 +0000
#
#     Added CQR Files
#
# commit 640a3d245cc803bf908b7f17b3813589e4f29ff5
# Author: Roel Hulsman <sann7266@ox.ac.uk>
# Date:   Mon Jul 25 14:28:49 2022 +0000
#
#     Added CQR Datasets
#
# commit 3a9b47cf8df2586865c593cd292fc25949adae73
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:40:30 2022 +0000
#
#     edited files
#
# commit 908ab06a55d3c70346feaace5fcb611ca57664c4
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:38:43 2022 +0000
#
#     edited file
#
# commit 3a0bc40148d2cf34a3bb1baaf3ad79b772f42d53
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:36:15 2022 +0000
#
#     edited file
#
# commit 9cd778fbe35290858fcbc6040e5283251c80c607
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:32:25 2022 +0000
#
#     edited file
#
# commit 20752b3d028a27a26a9a8d052017b0f5e57667a5
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:31:15 2022 +0000
#
#     edited file
#
# commit 57f989681320e503275a360fe9d7c0355f0039b6
# Author: Roel Hulsman <roel.hulsman@outlook.com>
# Date:   Fri Jul 22 17:21:25 2022 +0000
#
#     first commit
