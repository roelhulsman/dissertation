# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GitHub/dissertation

# !git config --global user.email "roel.hulsman@outlook.com"
# !git config --global user.name "Roel Hulsman"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/GitHub/dissertation

# %%
# !git add .
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   Create Repository.ipynb
# 	modified:   Link to GitHub.ipynb
# 	new file:   Push and Commit to GitHub.ipynb

# %%
# !git commit -m "edited file"
# Out:
# [main 3a0bc40] edited file
#  3 files changed, 3 insertions(+), 1 deletion(-)
#  create mode 100644 Create Repository.ipynb
#  create mode 100644 Push and Commit to GitHub.ipynb

# %%
# !git push -u origin "main"
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.58 KiB | 527.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# To https://github.com/roelhulsman/dissertation.git
#    9cd778f..3a0bc40  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
